# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
# Generate 2000 random coordinates
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
coordinates = list(lat_lngs)

# %%
#Use the citipy module to determine city based on latitude and longitude.
from citipy import citipy

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)

# %%
# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key

# %%
url ='https://api.openweathermap.org/data/2.5/weather?units=imperial&appid=' + weather_api_key 
print(url)
# Out:
# https://api.openweathermap.org/data/2.5/weather?units=imperial&appid=bceea34aff044c5810e5ca6a1acd9a39

# %%
# Import the time library and the datetime module from the datetime library 
import time
from datetime import datetime

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1 
    # Run an API request for each of the cities.
   
    try:
         # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_description = city_weather["weather"][0]['description']  
    
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                        "Lat": city_lat,
                        "Lng": city_lng,
                        "Max Temp": city_max_temp,
                        "Humidity": city_humidity,
                        "Cloudiness": city_clouds,
                        "Wind Speed": city_wind,
                        "Country": city_country,
                        "Current Description":city_description})
    except:
        print('error:skip city')
        pass
    
# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | lompoc
# Processing Record 2 of Set 1 | bargal
# error:skip city
# Processing Record 3 of Set 1 | hobyo
# Processing Record 4 of Set 1 | chernoyerkovskaya
# Processing Record 5 of Set 1 | busselton
# Processing Record 6 of Set 1 | ushuaia
# Processing Record 7 of Set 1 | fomboni
# Processing Record 8 of Set 1 | dawei
# Processing Record 9 of Set 1 | hobart
# Processing Record 10 of Set 1 | amderma
# error:skip city
# Processing Record 11 of Set 1 | hithadhoo
# Processing Record 12 of Set 1 | arraial do cabo
# Processing Record 13 of Set 1 | mahon
# Processing Record 14 of Set 1 | nouadhibou
# Processing Record 15 of Set 1 | tiksi
# Processing Record 16 of Set 1 | mandalgovi
# Processing Record 17 of Set 1 | codo
# Processing Record 18 of Set 1 | belaya gora
# Processing Record 19 of Set 1 | hermanus
# Processing Record 20 of Set 1 | chachoengsao
# Processing Record 21 of Set 1 | butaritari
# Processing Record 22 of Set 1 | mataura
# Processing Record 23 of Set 1 | qaanaaq
# Processing Record 24 of Set 1 | chokurdakh
# Processing Record 25 of Set 1 | rikitea
# Processing Record 26 of Set 1 | pierre
# Processing Record 27 of Set 1 | grand river south east
# error:skip city
# Processing Record 28 of Set 1 | nizhneyansk
# error:skip city
# Processing Record 29 of Set 1 | sovetskaya
# Processing Record 30 of Set 1 | tuatapere
# Processing Record 31 of Set 1 | katsuura
# Processing Record 32 of Set 1 | shubarshi
# Processing Record 33 of Set 1 | bathsheba
# Processing Record 34 of Set 1 | hokitika
# Processing Record 35 of Set 1 | nanortalik
# Processing Record 36 of Set 1 | katherine
# Processing Record 37 of Set 1 | khatanga
# Processing Record 38 of Set 1 | palmer
# Processing Record 39 of Set 1 | ilulissat
# Processing Record 40 of Set 1 | merced
# Processing Record 41 of Set 1 | tura
# Processing Record 42 of Set 1 | norman wells
# Processing Record 43 of Set 1 | avarua
# Processing Record 44 of Set 1 | berlevag
# Processing Record 45 of Set 1 | osakarovka
# Processing Record 46 of Set 1 | umzimvubu
# error:skip city
# Processing Record 47 of Set 1 | hilo
# Processing Record 48 of Set 1 | longyearbyen
# Processing Record 49 of Set 1 | san quintin
# Processing Record 50 of Set 1 | saint anthony
# Processing Record 1 of Set 2 | ahipara
# Processing Record 2 of Set 2 | saskylakh
# Processing Record 3 of Set 2 | tumannyy
# error:skip city
# Processing Record 4 of Set 2 | kruisfontein
# Processing Record 5 of Set 2 | kuhdasht
# Processing Record 6 of Set 2 | saint-philippe
# Processing Record 7 of Set 2 | vanimo
# Processing Record 8 of Set 2 | mumford
# Processing Record 9 of Set 2 | bambous virieux
# Processing Record 10 of Set 2 | umm kaddadah
# Processing Record 11 of Set 2 | severo-kurilsk
# Processing Record 12 of Set 2 | cockburn town
# Processing Record 13 of Set 2 | evensk
# Processing Record 14 of Set 2 | salalah
# Processing Record 15 of Set 2 | taolanaro
# error:skip city
# Processing Record 16 of Set 2 | bahar
# Processing Record 17 of Set 2 | atuona
# Processing Record 18 of Set 2 | pacific grove
# Processing Record 19 of Set 2 | mar del plata
# Processing Record 20 of Set 2 | sandusky
# Processing Record 21 of Set 2 | quatre cocos
# Processing Record 22 of Set 2 | ribeira grande
# Processing Record 23 of Set 2 | mehamn
# Processing Record 24 of Set 2 | vaitupu
# error:skip city
# Processing Record 25 of Set 2 | mareeba
# Processing Record 26 of Set 2 | lorengau
# Processing Record 27 of Set 2 | vaini
# Processing Record 28 of Set 2 | port elizabeth
# Processing Record 29 of Set 2 | kavaratti
# Processing Record 30 of Set 2 | port hedland
# Processing Record 31 of Set 2 | tasiilaq
# Processing Record 32 of Set 2 | puerto ayora
# Processing Record 33 of Set 2 | carnarvon
# Processing Record 34 of Set 2 | kapaa
# Processing Record 35 of Set 2 | hinton
# Processing Record 36 of Set 2 | jamestown
# Processing Record 37 of Set 2 | chicama
# Processing Record 38 of Set 2 | punta arenas
# Processing Record 39 of Set 2 | new norfolk
# Processing Record 40 of Set 2 | eureka
# Processing Record 41 of Set 2 | sao joao da barra
# Processing Record 42 of Set 2 | jeremie
# Processing Record 43 of Set 2 | vangaindrano
# Processing Record 44 of Set 2 | marcona
# error:skip city
# Processing Record 45 of Set 2 | komsomolskiy
# Processing Record 46 of Set 2 | upernavik
# Processing Record 47 of Set 2 | manoel urbano
# Processing Record 48 of Set 2 | fortuna
# Processing Record 49 of Set 2 | souillac
# Processing Record 50 of Set 2 | aklavik
# Processing Record 1 of Set 3 | dodge city
# Processing Record 2 of Set 3 | chagda
# error:skip city
# Processing Record 3 of Set 3 | umm lajj
# Processing Record 4 of Set 3 | dwarka
# Processing Record 5 of Set 3 | tuktoyaktuk
# Processing Record 6 of Set 3 | dunedin
# Processing Record 7 of Set 3 | belyy yar
# Processing Record 8 of Set 3 | ballstad
# error:skip city
# Processing Record 9 of Set 3 | samusu
# error:skip city
# Processing Record 10 of Set 3 | dikson
# Processing Record 11 of Set 3 | mathbaria
# Processing Record 12 of Set 3 | isangel
# Processing Record 13 of Set 3 | castro
# Processing Record 14 of Set 3 | torbay
# Processing Record 15 of Set 3 | san juan
# Processing Record 16 of Set 3 | albany
# Processing Record 17 of Set 3 | khani
# Processing Record 18 of Set 3 | lensk
# Processing Record 19 of Set 3 | illoqqortoormiut
# error:skip city
# Processing Record 20 of Set 3 | ancud
# Processing Record 21 of Set 3 | safford
# Processing Record 22 of Set 3 | paamiut
# Processing Record 23 of Set 3 | severnoye
# Processing Record 24 of Set 3 | angers
# Processing Record 25 of Set 3 | wanlaweyn
# Processing Record 26 of Set 3 | saurimo
# Processing Record 27 of Set 3 | namatanai
# Processing Record 28 of Set 3 | iqaluit
# Processing Record 29 of Set 3 | nguiu
# error:skip city
# Processing Record 30 of Set 3 | aljezur
# Processing Record 31 of Set 3 | mocambique
# error:skip city
# Processing Record 32 of Set 3 | lanxi
# Processing Record 33 of Set 3 | port alfred
# Processing Record 34 of Set 3 | san cristobal
# Processing Record 35 of Set 3 | nikolskoye
# Processing Record 36 of Set 3 | aflu
# error:skip city
# Processing Record 37 of Set 3 | nieuw amsterdam
# Processing Record 38 of Set 3 | guerrero negro
# Processing Record 39 of Set 3 | port lincoln
# Processing Record 40 of Set 3 | fort nelson
# Processing Record 41 of Set 3 | bredasdorp
# Processing Record 42 of Set 3 | bilma
# Processing Record 43 of Set 3 | kodiak
# Processing Record 44 of Set 3 | inta
# Processing Record 45 of Set 3 | otane
# Processing Record 46 of Set 3 | vestmannaeyjar
# Processing Record 47 of Set 3 | east london
# Processing Record 48 of Set 3 | camacha
# Processing Record 49 of Set 3 | batsfjord
# Processing Record 50 of Set 3 | cidreira
# Processing Record 1 of Set 4 | kaitangata
# Processing Record 2 of Set 4 | nepomuk
# Processing Record 3 of Set 4 | touros
# Processing Record 4 of Set 4 | hay river
# Processing Record 5 of Set 4 | bluff
# Processing Record 6 of Set 4 | tokzar
# error:skip city
# Processing Record 7 of Set 4 | newport
# Processing Record 8 of Set 4 | paharpur
# Processing Record 9 of Set 4 | bengkulu
# Processing Record 10 of Set 4 | labuhan
# Processing Record 11 of Set 4 | thompson
# Processing Record 12 of Set 4 | la asuncion
# Processing Record 13 of Set 4 | boyolangu
# Processing Record 14 of Set 4 | barentsburg
# error:skip city
# Processing Record 15 of Set 4 | georgetown
# Processing Record 16 of Set 4 | chapais
# Processing Record 17 of Set 4 | kamaishi
# Processing Record 18 of Set 4 | sentyabrskiy
# error:skip city
# Processing Record 19 of Set 4 | victoria
# Processing Record 20 of Set 4 | codajas
# Processing Record 21 of Set 4 | cabo san lucas
# Processing Record 22 of Set 4 | buta
# Processing Record 23 of Set 4 | coquimbo
# Processing Record 24 of Set 4 | rudbar
# Processing Record 25 of Set 4 | ponta do sol
# Processing Record 26 of Set 4 | mesimerion
# Processing Record 27 of Set 4 | nicholasville
# Processing Record 28 of Set 4 | mys shmidta
# error:skip city
# Processing Record 29 of Set 4 | andevoranto
# error:skip city
# Processing Record 30 of Set 4 | hami
# Processing Record 31 of Set 4 | umea
# Processing Record 32 of Set 4 | kosikha
# Processing Record 33 of Set 4 | weiser
# Processing Record 34 of Set 4 | leningradskiy
# Processing Record 35 of Set 4 | hasaki
# Processing Record 36 of Set 4 | goderich
# Processing Record 37 of Set 4 | ruatoria
# error:skip city
# Processing Record 38 of Set 4 | sribne
# Processing Record 39 of Set 4 | san rafael
# Processing Record 40 of Set 4 | okhotsk
# Processing Record 41 of Set 4 | gwadar
# Processing Record 42 of Set 4 | batemans bay
# Processing Record 43 of Set 4 | rungata
# error:skip city
# Processing Record 44 of Set 4 | bethel
# Processing Record 45 of Set 4 | carlyle
# Processing Record 46 of Set 4 | watsa
# Processing Record 47 of Set 4 | tommot
# Processing Record 48 of Set 4 | tautira
# Processing Record 49 of Set 4 | port-gentil
# Processing Record 50 of Set 4 | olafsvik
# Processing Record 1 of Set 5 | saldanha
# Processing Record 2 of Set 5 | springdale
# Processing Record 3 of Set 5 | sur
# Processing Record 4 of Set 5 | oudtshoorn
# Processing Record 5 of Set 5 | santarem
# Processing Record 6 of Set 5 | araouane
# Processing Record 7 of Set 5 | chuy
# Processing Record 8 of Set 5 | attawapiskat
# error:skip city
# Processing Record 9 of Set 5 | luderitz
# Processing Record 10 of Set 5 | tsihombe
# error:skip city
# Processing Record 11 of Set 5 | sept-iles
# Processing Record 12 of Set 5 | yellowknife
# Processing Record 13 of Set 5 | ixtapa
# Processing Record 14 of Set 5 | salinas
# Processing Record 15 of Set 5 | ostrovnoy
# Processing Record 16 of Set 5 | townsville
# Processing Record 17 of Set 5 | lebu
# Processing Record 18 of Set 5 | iquitos
# Processing Record 19 of Set 5 | clyde river
# Processing Record 20 of Set 5 | davila
# Processing Record 21 of Set 5 | ulaangom
# Processing Record 22 of Set 5 | moree
# Processing Record 23 of Set 5 | ridgecrest
# Processing Record 24 of Set 5 | coihaique
# Processing Record 25 of Set 5 | kavieng
# Processing Record 26 of Set 5 | port blair
# Processing Record 27 of Set 5 | abu dhabi
# Processing Record 28 of Set 5 | chingirlau
# Processing Record 29 of Set 5 | filadelfia
# Processing Record 30 of Set 5 | teya
# Processing Record 31 of Set 5 | eyl
# Processing Record 32 of Set 5 | mnogovershinnyy
# Processing Record 33 of Set 5 | saint george
# Processing Record 34 of Set 5 | khorixas
# Processing Record 35 of Set 5 | srednekolymsk
# Processing Record 36 of Set 5 | pyapon
# Processing Record 37 of Set 5 | geraldton
# Processing Record 38 of Set 5 | itoman
# Processing Record 39 of Set 5 | sorland
# Processing Record 40 of Set 5 | longkou
# Processing Record 41 of Set 5 | buala
# Processing Record 42 of Set 5 | ozernovskiy
# Processing Record 43 of Set 5 | kingori
# Processing Record 44 of Set 5 | chihuahua
# Processing Record 45 of Set 5 | cape town
# Processing Record 46 of Set 5 | puerto cabezas
# Processing Record 47 of Set 5 | la ronge
# Processing Record 48 of Set 5 | batagay-alyta
# Processing Record 49 of Set 5 | caraballeda
# Processing Record 50 of Set 5 | carutapera
# Processing Record 1 of Set 6 | vung tau
# Processing Record 2 of Set 6 | chacabuco
# Processing Record 3 of Set 6 | ambodifototra
# error:skip city
# Processing Record 4 of Set 6 | aksum
# Processing Record 5 of Set 6 | arzamas
# Processing Record 6 of Set 6 | rafiganj
# Processing Record 7 of Set 6 | donskoye
# Processing Record 8 of Set 6 | kiama
# Processing Record 9 of Set 6 | doka
# Processing Record 10 of Set 6 | hamilton
# Processing Record 11 of Set 6 | oksfjord
# Processing Record 12 of Set 6 | yeppoon
# Processing Record 13 of Set 6 | barrow
# Processing Record 14 of Set 6 | talnakh
# Processing Record 15 of Set 6 | nizhnyaya tavda
# Processing Record 16 of Set 6 | panorama
# Processing Record 17 of Set 6 | bow island
# Processing Record 18 of Set 6 | betafo
# Processing Record 19 of Set 6 | poum
# Processing Record 20 of Set 6 | rawson
# Processing Record 21 of Set 6 | owando
# Processing Record 22 of Set 6 | vila franca do campo
# Processing Record 23 of Set 6 | omsukchan
# Processing Record 24 of Set 6 | lucapa
# Processing Record 25 of Set 6 | leh
# Processing Record 26 of Set 6 | tiarei
# Processing Record 27 of Set 6 | ichnya
# Processing Record 28 of Set 6 | langenhagen
# Processing Record 29 of Set 6 | calbiga
# Processing Record 30 of Set 6 | liverpool
# Processing Record 31 of Set 6 | orichi
# Processing Record 32 of Set 6 | noumea
# Processing Record 33 of Set 6 | abu samrah
# Processing Record 34 of Set 6 | badarpur
# Processing Record 35 of Set 6 | bulungu
# Processing Record 36 of Set 6 | cayhagan
# Processing Record 37 of Set 6 | cap malheureux
# Processing Record 38 of Set 6 | haimen
# Processing Record 39 of Set 6 | san jose
# Processing Record 40 of Set 6 | karakendzha
# error:skip city
# Processing Record 41 of Set 6 | rio gallegos
# Processing Record 42 of Set 6 | laguna
# Processing Record 43 of Set 6 | derbent
# Processing Record 44 of Set 6 | shieli
# Processing Record 45 of Set 6 | farafangana
# Processing Record 46 of Set 6 | avanigadda
# Processing Record 47 of Set 6 | lesnoye
# Processing Record 48 of Set 6 | tamale
# Processing Record 49 of Set 6 | puerto madero
# Processing Record 50 of Set 6 | neuquen
# Processing Record 1 of Set 7 | haines junction
# Processing Record 2 of Set 7 | dustlik
# Processing Record 3 of Set 7 | charters towers
# Processing Record 4 of Set 7 | korla
# Processing Record 5 of Set 7 | winnemucca
# Processing Record 6 of Set 7 | dingle
# Processing Record 7 of Set 7 | erzurum
# Processing Record 8 of Set 7 | constantine
# Processing Record 9 of Set 7 | husavik
# Processing Record 10 of Set 7 | isla del bosque
# Processing Record 11 of Set 7 | saint-georges
# Processing Record 12 of Set 7 | verkhnevilyuysk
# Processing Record 13 of Set 7 | siguiri
# Processing Record 14 of Set 7 | tatui
# Processing Record 15 of Set 7 | zavetnoye
# Processing Record 16 of Set 7 | hudson bay
# Processing Record 17 of Set 7 | sitka
# Processing Record 18 of Set 7 | bam
# Processing Record 19 of Set 7 | rio grande
# Processing Record 20 of Set 7 | krasnoselkup
# Processing Record 21 of Set 7 | nantucket
# Processing Record 22 of Set 7 | pisco
# Processing Record 23 of Set 7 | ust-tsilma
# Processing Record 24 of Set 7 | cuamba
# Processing Record 25 of Set 7 | te anau
# Processing Record 26 of Set 7 | chatra
# Processing Record 27 of Set 7 | la macarena
# Processing Record 28 of Set 7 | sao filipe
# Processing Record 29 of Set 7 | livingston
# Processing Record 30 of Set 7 | narsaq
# Processing Record 31 of Set 7 | tateyama
# Processing Record 32 of Set 7 | corinto
# Processing Record 33 of Set 7 | borovoy
# Processing Record 34 of Set 7 | belushya guba
# error:skip city
# Processing Record 35 of Set 7 | inderborskiy
# error:skip city
# Processing Record 36 of Set 7 | anqiu
# Processing Record 37 of Set 7 | saint-michel-des-saints
# Processing Record 38 of Set 7 | walvis bay
# Processing Record 39 of Set 7 | chernyshkovskiy
# Processing Record 40 of Set 7 | rorvik
# Processing Record 41 of Set 7 | tambopata
# Processing Record 42 of Set 7 | aban
# Processing Record 43 of Set 7 | presidencia roque saenz pena
# Processing Record 44 of Set 7 | katangli
# Processing Record 45 of Set 7 | belchatow
# Processing Record 46 of Set 7 | mount isa
# Processing Record 47 of Set 7 | tucuma
# Processing Record 48 of Set 7 | sug-aksy
# error:skip city
# Processing Record 49 of Set 7 | dolbeau
# error:skip city
# Processing Record 50 of Set 7 | nushki
# Processing Record 1 of Set 8 | pascagoula
# Processing Record 2 of Set 8 | bucerias
# Processing Record 3 of Set 8 | lagoa
# Processing Record 4 of Set 8 | nueva gerona
# Processing Record 5 of Set 8 | lolua
# error:skip city
# Processing Record 6 of Set 8 | puerto quijarro
# Processing Record 7 of Set 8 | port hardy
# Processing Record 8 of Set 8 | marawi
# Processing Record 9 of Set 8 | kamina
# Processing Record 10 of Set 8 | hirara
# Processing Record 11 of Set 8 | kabansk
# Processing Record 12 of Set 8 | pevek
# Processing Record 13 of Set 8 | los llanos de aridane
# Processing Record 14 of Set 8 | ponta delgada
# Processing Record 15 of Set 8 | kanigiri
# Processing Record 16 of Set 8 | galiwinku
# error:skip city
# Processing Record 17 of Set 8 | nome
# Processing Record 18 of Set 8 | bakchar
# Processing Record 19 of Set 8 | sultanpur
# Processing Record 20 of Set 8 | mount gambier
# Processing Record 21 of Set 8 | san patricio
# Processing Record 22 of Set 8 | portales
# Processing Record 23 of Set 8 | plettenberg bay
# Processing Record 24 of Set 8 | prado
# Processing Record 25 of Set 8 | cherskiy
# Processing Record 26 of Set 8 | santiago de chuco
# Processing Record 27 of Set 8 | portland
# Processing Record 28 of Set 8 | ada
# Processing Record 29 of Set 8 | kungurtug
# Processing Record 30 of Set 8 | marsabit
# Processing Record 31 of Set 8 | kovrov
# Processing Record 32 of Set 8 | nichinan
# Processing Record 33 of Set 8 | tabou
# Processing Record 34 of Set 8 | fairbanks
# Processing Record 35 of Set 8 | dhidhdhoo
# Processing Record 36 of Set 8 | koslan
# Processing Record 37 of Set 8 | saint-augustin
# Processing Record 38 of Set 8 | karaul
# error:skip city
# Processing Record 39 of Set 8 | muros
# Processing Record 40 of Set 8 | provideniya
# Processing Record 41 of Set 8 | fenoarivo
# Processing Record 42 of Set 8 | morro bay
# Processing Record 43 of Set 8 | tikhvin
# Processing Record 44 of Set 8 | burkhala
# error:skip city
# Processing Record 45 of Set 8 | beloha
# Processing Record 46 of Set 8 | powell
# Processing Record 47 of Set 8 | broken hill
# Processing Record 48 of Set 8 | khomeyn
# Processing Record 49 of Set 8 | viedma
# Processing Record 50 of Set 8 | mahajanga
# Processing Record 1 of Set 9 | zomba
# Processing Record 2 of Set 9 | baiyin
# Processing Record 3 of Set 9 | rosarito
# Processing Record 4 of Set 9 | vila
# Processing Record 5 of Set 9 | kenai
# Processing Record 6 of Set 9 | savelugu
# Processing Record 7 of Set 9 | ljutomer
# Processing Record 8 of Set 9 | grootfontein
# Processing Record 9 of Set 9 | nhulunbuy
# Processing Record 10 of Set 9 | kirakira
# Processing Record 11 of Set 9 | beringovskiy
# Processing Record 12 of Set 9 | kununurra
# Processing Record 13 of Set 9 | povenets
# Processing Record 14 of Set 9 | saint-joseph
# Processing Record 15 of Set 9 | hirado
# Processing Record 16 of Set 9 | kieta
# Processing Record 17 of Set 9 | tainan
# Processing Record 18 of Set 9 | codrington
# Processing Record 19 of Set 9 | lexington
# Processing Record 20 of Set 9 | juneau
# Processing Record 21 of Set 9 | igarka
# Processing Record 22 of Set 9 | kutum
# Processing Record 23 of Set 9 | acajutla
# Processing Record 24 of Set 9 | nautla
# Processing Record 25 of Set 9 | ashti
# Processing Record 26 of Set 9 | stornoway
# Processing Record 27 of Set 9 | akhaldaba
# Processing Record 28 of Set 9 | tuy hoa
# Processing Record 29 of Set 9 | ventspils
# Processing Record 30 of Set 9 | oeiras do para
# Processing Record 31 of Set 9 | baruun-urt
# Processing Record 32 of Set 9 | marsa matruh
# Processing Record 33 of Set 9 | deputatskiy
# Processing Record 34 of Set 9 | biaora
# Processing Record 35 of Set 9 | hit
# Processing Record 36 of Set 9 | samarai
# Processing Record 37 of Set 9 | lata
# Processing Record 38 of Set 9 | north bend
# Processing Record 39 of Set 9 | celestun
# Processing Record 40 of Set 9 | mangrol
# Processing Record 41 of Set 9 | perelyub
# Processing Record 42 of Set 9 | butembo
# Processing Record 43 of Set 9 | haysville
# Processing Record 44 of Set 9 | hofn
# Processing Record 45 of Set 9 | kerema
# Processing Record 46 of Set 9 | agucadoura
# Processing Record 47 of Set 9 | baykit
# Processing Record 48 of Set 9 | mouzakion
# error:skip city
# Processing Record 49 of Set 9 | whitehorse
# Processing Record 50 of Set 9 | a coruna
# Processing Record 1 of Set 10 | aswan
# Processing Record 2 of Set 10 | lubbock
# Processing Record 3 of Set 10 | makakilo city
# Processing Record 4 of Set 10 | kaniama
# Processing Record 5 of Set 10 | monrovia
# Processing Record 6 of Set 10 | swan river
# Processing Record 7 of Set 10 | lebyazhye
# Processing Record 8 of Set 10 | iralaya
# Processing Record 9 of Set 10 | port angeles
# Processing Record 10 of Set 10 | upington
# Processing Record 11 of Set 10 | warmbad
# Processing Record 12 of Set 10 | pedernales
# Processing Record 13 of Set 10 | acari
# Processing Record 14 of Set 10 | banda aceh
# Processing Record 15 of Set 10 | ugoofaaru
# Processing Record 16 of Set 10 | oranjemund
# Processing Record 17 of Set 10 | kamenka
# Processing Record 18 of Set 10 | talcahuano
# Processing Record 19 of Set 10 | luchegorsk
# Processing Record 20 of Set 10 | margate
# Processing Record 21 of Set 10 | sinnamary
# Processing Record 22 of Set 10 | krasnovishersk
# Processing Record 23 of Set 10 | kodinsk
# Processing Record 24 of Set 10 | jyvaskyla
# Processing Record 25 of Set 10 | magadan
# Processing Record 26 of Set 10 | sembe
# Processing Record 27 of Set 10 | belmopan
# Processing Record 28 of Set 10 | atar
# Processing Record 29 of Set 10 | esperance
# Processing Record 30 of Set 10 | kerrville
# Processing Record 31 of Set 10 | saleaula
# error:skip city
# Processing Record 32 of Set 10 | comodoro rivadavia
# Processing Record 33 of Set 10 | bonoua
# Processing Record 34 of Set 10 | port moresby
# Processing Record 35 of Set 10 | kahului
# Processing Record 36 of Set 10 | balugaon
# Processing Record 37 of Set 10 | el alto
# Processing Record 38 of Set 10 | grande prairie
# Processing Record 39 of Set 10 | qasigiannguit
# Processing Record 40 of Set 10 | gardez
# Processing Record 41 of Set 10 | grindavik
# Processing Record 42 of Set 10 | faya
# Processing Record 43 of Set 10 | labutta
# error:skip city
# Processing Record 44 of Set 10 | aykhal
# Processing Record 45 of Set 10 | kirkwood
# Processing Record 46 of Set 10 | launceston
# Processing Record 47 of Set 10 | solovetskiy
# error:skip city
# Processing Record 48 of Set 10 | aden
# Processing Record 49 of Set 10 | diego de almagro
# Processing Record 50 of Set 10 | gat
# Processing Record 1 of Set 11 | pandan
# Processing Record 2 of Set 11 | cayenne
# Processing Record 3 of Set 11 | qaqortoq
# Processing Record 4 of Set 11 | taunggyi
# Processing Record 5 of Set 11 | cumaribo
# error:skip city
# Processing Record 6 of Set 11 | faanui
# Processing Record 7 of Set 11 | garowe
# Processing Record 8 of Set 11 | shingu
# Processing Record 9 of Set 11 | raga
# Processing Record 10 of Set 11 | alta floresta
# Processing Record 11 of Set 11 | vardo
# Processing Record 12 of Set 11 | pau dos ferros
# Processing Record 13 of Set 11 | vila velha
# Processing Record 14 of Set 11 | zolotinka
# error:skip city
# Processing Record 15 of Set 11 | fare
# Processing Record 16 of Set 11 | brooks
# Processing Record 17 of Set 11 | paraiso
# Processing Record 18 of Set 11 | ngunguru
# Processing Record 19 of Set 11 | vysokogornyy
# Processing Record 20 of Set 11 | waipawa
# Processing Record 21 of Set 11 | anshun
# Processing Record 22 of Set 11 | banjar
# Processing Record 23 of Set 11 | halalo
# error:skip city
# Processing Record 24 of Set 11 | gigmoto
# Processing Record 25 of Set 11 | saint-pierre
# Processing Record 26 of Set 11 | kharod
# Processing Record 27 of Set 11 | mahebourg
# Processing Record 28 of Set 11 | muriwai beach
# Processing Record 29 of Set 11 | izhma
# Processing Record 30 of Set 11 | rosetta
# Processing Record 31 of Set 11 | skibbereen
# Processing Record 32 of Set 11 | klaksvik
# Processing Record 33 of Set 11 | lae
# Processing Record 34 of Set 11 | zhanakorgan
# Processing Record 35 of Set 11 | flinders
# Processing Record 36 of Set 11 | atambua
# Processing Record 37 of Set 11 | ketchikan
# Processing Record 38 of Set 11 | sujiatun
# Processing Record 39 of Set 11 | kazalinsk
# error:skip city
# Processing Record 40 of Set 11 | naze
# Processing Record 41 of Set 11 | maunabo
# Processing Record 42 of Set 11 | rawannawi
# error:skip city
# Processing Record 43 of Set 11 | bagdarin
# Processing Record 44 of Set 11 | hsinying
# error:skip city
# Processing Record 45 of Set 11 | boende
# Processing Record 46 of Set 11 | okha
# Processing Record 47 of Set 11 | college
# Processing Record 48 of Set 11 | brantford
# Processing Record 49 of Set 11 | port-cartier
# Processing Record 50 of Set 11 | tashtyp
# Processing Record 1 of Set 12 | batesville
# Processing Record 2 of Set 12 | kargasok
# Processing Record 3 of Set 12 | saint-gaudens
# Processing Record 4 of Set 12 | susuman
# Processing Record 5 of Set 12 | almeirim
# Processing Record 6 of Set 12 | la massana
# Processing Record 7 of Set 12 | itaituba
# Processing Record 8 of Set 12 | maragogi
# Processing Record 9 of Set 12 | kudahuvadhoo
# Processing Record 10 of Set 12 | paradwip
# error:skip city
# Processing Record 11 of Set 12 | mayumba
# Processing Record 12 of Set 12 | novo oriente
# Processing Record 13 of Set 12 | gallup
# Processing Record 14 of Set 12 | shimanovsk
# Processing Record 15 of Set 12 | mersing
# Processing Record 16 of Set 12 | bolondron
# Processing Record 17 of Set 12 | pangnirtung
# Processing Record 18 of Set 12 | paka
# Processing Record 19 of Set 12 | atasu
# Processing Record 20 of Set 12 | axim
# Processing Record 21 of Set 12 | ossora
# Processing Record 22 of Set 12 | hambantota
# Processing Record 23 of Set 12 | dembi dolo
# Processing Record 24 of Set 12 | karratha
# Processing Record 25 of Set 12 | faro
# Processing Record 26 of Set 12 | santiago
# Processing Record 27 of Set 12 | villa carlos paz
# Processing Record 28 of Set 12 | myaundzha
# Processing Record 29 of Set 12 | haibowan
# error:skip city
# Processing Record 30 of Set 12 | lavrentiya
# Processing Record 31 of Set 12 | toliary
# error:skip city
# Processing Record 32 of Set 12 | yulara
# Processing Record 33 of Set 12 | la palma
# Processing Record 34 of Set 12 | marienburg
# Processing Record 35 of Set 12 | barranca
# Processing Record 36 of Set 12 | rawlins
# Processing Record 37 of Set 12 | harbour breton
# Processing Record 38 of Set 12 | jaicos
# Processing Record 39 of Set 12 | cahul
# Processing Record 40 of Set 12 | terny
# Processing Record 41 of Set 12 | biak
# Processing Record 42 of Set 12 | paita
# Processing Record 43 of Set 12 | altamira
# Processing Record 44 of Set 12 | mao
# Processing Record 45 of Set 12 | moron
# Processing Record 46 of Set 12 | belmonte
# Processing Record 47 of Set 12 | ulaanbaatar
# Processing Record 48 of Set 12 | iquique
# Processing Record 49 of Set 12 | anadyr
# Processing Record 50 of Set 12 | tual
# Processing Record 1 of Set 13 | krasnaya gora
# Processing Record 2 of Set 13 | youghal
# Processing Record 3 of Set 13 | jarjis
# error:skip city
# Processing Record 4 of Set 13 | the valley
# Processing Record 5 of Set 13 | mardin
# Processing Record 6 of Set 13 | sola
# Processing Record 7 of Set 13 | inuvik
# Processing Record 8 of Set 13 | bondowoso
# Processing Record 9 of Set 13 | rapar
# Processing Record 10 of Set 13 | sahuaripa
# Processing Record 11 of Set 13 | henties bay
# Processing Record 12 of Set 13 | pallasovka
# Processing Record 13 of Set 13 | mednogorsk
# Processing Record 14 of Set 13 | airai
# Processing Record 15 of Set 13 | jalu
# Processing Record 16 of Set 13 | luohe
# Processing Record 17 of Set 13 | birjand
# Processing Record 18 of Set 13 | homer
# Processing Record 19 of Set 13 | mogadishu
# Processing Record 20 of Set 13 | alofi
# Processing Record 21 of Set 13 | bilibino
# Processing Record 22 of Set 13 | abha
# Processing Record 23 of Set 13 | brae
# Processing Record 24 of Set 13 | vysokovsk
# Processing Record 25 of Set 13 | srandakan
# Processing Record 26 of Set 13 | jaipur hat
# error:skip city
# Processing Record 27 of Set 13 | maldonado
# Processing Record 28 of Set 13 | puksoozero
# Processing Record 29 of Set 13 | dongning
# Processing Record 30 of Set 13 | tabiauea
# error:skip city
# Processing Record 31 of Set 13 | sarai
# Processing Record 32 of Set 13 | takoradi
# Processing Record 33 of Set 13 | alice springs
# Processing Record 34 of Set 13 | aseri
# Processing Record 35 of Set 13 | barcelos
# Processing Record 36 of Set 13 | pandamatenga
# Processing Record 37 of Set 13 | malangwa
# Processing Record 38 of Set 13 | acapulco
# Processing Record 39 of Set 13 | zhigansk
# Processing Record 40 of Set 13 | xining
# Processing Record 41 of Set 13 | batagay
# Processing Record 42 of Set 13 | yanchukan
# error:skip city
# Processing Record 43 of Set 13 | yar-sale
# Processing Record 44 of Set 13 | kallidaikurichchi
# Processing Record 45 of Set 13 | hutchinson
# Processing Record 46 of Set 13 | marystown
# Processing Record 47 of Set 13 | gorno-chuyskiy
# error:skip city
# Processing Record 48 of Set 13 | santiago del estero
# Processing Record 49 of Set 13 | chandpur
# Processing Record 50 of Set 13 | san rafael del sur
# Processing Record 1 of Set 14 | webuye
# Processing Record 2 of Set 14 | bawisan
# error:skip city
# Processing Record 3 of Set 14 | florida
# Processing Record 4 of Set 14 | sobolevo
# Processing Record 5 of Set 14 | burica
# error:skip city
# Processing Record 6 of Set 14 | natal
# Processing Record 7 of Set 14 | pangody
# Processing Record 8 of Set 14 | novomyshastovskaya
# Processing Record 9 of Set 14 | kovdor
# Processing Record 10 of Set 14 | njombe
# Processing Record 11 of Set 14 | westport
# Processing Record 12 of Set 14 | dindori
# Processing Record 13 of Set 14 | caravelas
# Processing Record 14 of Set 14 | maxixe
# Processing Record 15 of Set 14 | labrea
# Processing Record 16 of Set 14 | salinopolis
# Processing Record 17 of Set 14 | satitoa
# error:skip city
# Processing Record 18 of Set 14 | warrnambool
# Processing Record 19 of Set 14 | garden city
# Processing Record 20 of Set 14 | sainte-suzanne
# Processing Record 21 of Set 14 | ilebo
# Processing Record 22 of Set 14 | tyukhtet
# Processing Record 23 of Set 14 | adrar
# Processing Record 24 of Set 14 | mayo
# Processing Record 25 of Set 14 | alyangula
# Processing Record 26 of Set 14 | kerteh
# error:skip city
# Processing Record 27 of Set 14 | kloulklubed
# Processing Record 28 of Set 14 | coahuayana
# Processing Record 29 of Set 14 | lamu
# Processing Record 30 of Set 14 | russkoye
# Processing Record 31 of Set 14 | neka
# Processing Record 32 of Set 14 | kendari
# Processing Record 33 of Set 14 | roald
# Processing Record 34 of Set 14 | farah
# Processing Record 35 of Set 14 | inyonga
# Processing Record 36 of Set 14 | san juan de los morros
# Processing Record 37 of Set 14 | nioro
# Processing Record 38 of Set 14 | rincon
# Processing Record 39 of Set 14 | maneadero
# Processing Record 40 of Set 14 | cabedelo
# Processing Record 41 of Set 14 | henzada
# error:skip city
# Processing Record 42 of Set 14 | zhangjiakou
# Processing Record 43 of Set 14 | vuktyl
# Processing Record 44 of Set 14 | thinadhoo
# Processing Record 45 of Set 14 | mazamari
# Processing Record 46 of Set 14 | kentau
# Processing Record 47 of Set 14 | urumqi
# Processing Record 48 of Set 14 | sisimiut
# Processing Record 49 of Set 14 | ocampo
# Processing Record 50 of Set 14 | shenjiamen
# Processing Record 1 of Set 15 | san andres
# Processing Record 2 of Set 15 | benito juarez
# Processing Record 3 of Set 15 | mazatlan
# Processing Record 4 of Set 15 | kismayo
# Processing Record 5 of Set 15 | aasiaat
# Processing Record 6 of Set 15 | balikpapan
# Processing Record 7 of Set 15 | buenos aires
# Processing Record 8 of Set 15 | balkhash
# Processing Record 9 of Set 15 | darnah
# Processing Record 10 of Set 15 | hovd
# Processing Record 11 of Set 15 | kalabo
# Processing Record 12 of Set 15 | jiexiu
# Processing Record 13 of Set 15 | khasan
# Processing Record 14 of Set 15 | bandarbeyla
# Processing Record 15 of Set 15 | lombardia
# Processing Record 16 of Set 15 | asfi
# Processing Record 17 of Set 15 | carhuamayo
# Processing Record 18 of Set 15 | champerico
# Processing Record 19 of Set 15 | castro verde
# Processing Record 20 of Set 15 | kuche
# error:skip city
# Processing Record 21 of Set 15 | castlemaine
# Processing Record 22 of Set 15 | wuwei
# Processing Record 23 of Set 15 | fortuna foothills
# Processing Record 24 of Set 15 | dzhusaly
# error:skip city
# Processing Record 25 of Set 15 | saint simons
# Processing Record 26 of Set 15 | marsh harbour
# Processing Record 27 of Set 15 | maloy
# Processing Record 28 of Set 15 | santa maria
# Processing Record 29 of Set 15 | antalaha
# Processing Record 30 of Set 15 | hanko
# Processing Record 31 of Set 15 | vikhorevka
# Processing Record 32 of Set 15 | ngukurr
# error:skip city
# Processing Record 33 of Set 15 | caluquembe
# Processing Record 34 of Set 15 | torbat-e jam
# Processing Record 35 of Set 15 | skjervoy
# Processing Record 36 of Set 15 | can
# Processing Record 37 of Set 15 | sampit
# Processing Record 38 of Set 15 | qingdao
# Processing Record 39 of Set 15 | malkangiri
# Processing Record 40 of Set 15 | wladyslawowo
# Processing Record 41 of Set 15 | palabuhanratu
# error:skip city
# Processing Record 42 of Set 15 | malayal
# Processing Record 43 of Set 15 | yazd
# Processing Record 44 of Set 15 | bagar
# Processing Record 45 of Set 15 | sweetwater
# Processing Record 46 of Set 15 | asau
# Processing Record 47 of Set 15 | basco
# Processing Record 48 of Set 15 | barra do garcas
# Processing Record 49 of Set 15 | vlagtwedde
# Processing Record 50 of Set 15 | konya
# Processing Record 1 of Set 16 | khonuu
# error:skip city
# Processing Record 2 of Set 16 | puerto colombia
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data, columns = ['City','Country','Lat','Lng','Max Temp','Humidity','Cloudiness','Wind Speed', 'Current Description'])
city_data_df
# Out:
#                   City Country      Lat       Lng  Max Temp  Humidity  \
# 0               Lompoc      US  34.6391 -120.4579     68.02        65
# 1                Hobyo      SO   5.3505   48.5268     83.77        80
# 2    Chernoyerkovskaya      RU  45.4331   37.7686     53.24        77
# 3            Busselton      AU -33.6500  115.3333     61.48        87
# 4              Ushuaia      AR -54.8000  -68.3000     46.06        71
# ..                 ...     ...      ...       ...       ...       ...
# 684              Basco      PH  20.4487  121.9702     77.09        82
# 685    Barra Do Garcas      BR -15.8900  -52.2567     93.78        38
# 686         Vlagtwedde      NL  53.0275    7.1083     59.25        64
# 687              Konya      TR  38.1667   32.5000     53.65        40
# 688    Puerto Colombia      CO  10.9878  -74.9547     78.89        76
#
#      Cloudiness  Wind Speed Current Description
# 0             0       17.00           clear sky
# 1            44       14.27    scattered clouds
# 2            73        5.91       broken clouds
# 3            94        5.08     overcast clouds
# 4            75        4.61       broken clouds
# ..          ...         ...                 ...
# 684          51       16.69       broken clouds
# 685          40        3.44    scattered clouds
# 686           0        7.83           clear sky
# 687           0        1.95           clear sky
# 688          27       12.26    scattered clouds
#
# [689 rows x 9 columns]

# %%
import os

# %%
os.getcwd()
# Out:
# 'C:\\Users\\tavio\\Documents\\Data_Camp\\Analysis Folder\\World_Weather_Analysis\\Weather_Database'

# %%
# Create the output file (CSV).
output_data_file = "C:\\Users\\tavio\\Documents\\Data_Camp\\Analysis Folder\\World_Weather_Analysis\\Weather_Database\\WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")

# %%
city_data
# Out:
# [{'City': 'Lompoc',
#   'Lat': 34.6391,
#   'Lng': -120.4579,
#   'Max Temp': 68.02,
#   'Humidity': 65,
#   'Cloudiness': 0,
#   'Wind Speed': 17,
#   'Country': 'US',
#   'Current Description': 'clear sky'},
#  {'City': 'Hobyo',
#   'Lat': 5.3505,
#   'Lng': 48.5268,
#   'Max Temp': 83.77,
#   'Humidity': 80,
#   'Cloudiness': 44,
#   'Wind Speed': 14.27,
#   'Country': 'SO',
#   'Current Description': 'scattered clouds'},
#  {'City': 'Chernoyerkovskaya',
#   'Lat': 45.4331,
#   'Lng': 37.7686,
#   'Max Temp': 53.24,
#   'Humidity': 77,
#   'Cloudiness': 73,
#   'Wind Speed': 5.91,
#   'Country': 'RU',
#   'Current Description': 'broken clouds'},
#  {'City': 'Busselton',
#   'Lat': -33.65,
#   'Lng': 115.3333,
#   'Max Temp': 61.48,
#   'Humidity': 87,
#   'Cloudiness': 94,
#   'Wind Speed': 5.08,
#   'Country': 'AU',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Ushuaia',
#   'Lat': -54.8,
#   'Lng': -68.3,
#   'Max Temp': 46.06,
#   'Humidity': 71,
#   'Cloudiness': 75,
#   'Wind Speed': 4.61,
#   'Country': 'AR',
#   'Current Description': 'broken clouds'},
#  {'City': 'Fomboni',
#   'Lat': -12.28,
#   'Lng': 43.7425,
#   'Max Temp': 83.46,
#   'Humidity': 73,
#   'Cloudiness': 24,
#   'Wind Speed': 9.1,
#   'Country': 'KM',
#   'Current Description': 'few clouds'},
#  {'City': 'Dawei',
#   'Lat': 14.0833,
#   'Lng': 98.2,
#   'Max Temp': 76.69,
#   'Humidity': 90,
#   'Cloudiness': 100,
#   'Wind Speed': 2.77,
#   'Country': 'MM',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Hobart',
#   'Lat': -42.8794,
#   'Lng': 147.3294,
#   'Max Temp': 53.26,
#   'Humidity': 81,
#   'Cloudiness': 100,
#   'Wind Speed': 4.61,
#   'Country': 'AU',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Hithadhoo',
#   'Lat': -0.6,
#   'Lng': 73.0833,
#   'Max Temp': 83.46,
#   'Humidity': 71,
#   'Cloudiness': 100,
#   'Wind Speed': 2.91,
#   'Country': 'MV',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Arraial Do Cabo',
#   'Lat': -22.9661,
#   'Lng': -42.0278,
#   'Max Temp': 76.86,
#   'Humidity': 69,
#   'Cloudiness': 40,
#   'Wind Speed': 8.05,
#   'Country': 'BR',
#   'Current Description': 'scattered clouds'},
#  {'City': 'Mahon',
#   'Lat': 39.8885,
#   'Lng': 4.2658,
#   'Max Temp': 59.56,
#   'Humidity': 72,
#   'Cloudiness': 0,
#   'Wind Speed': 6.91,
#   'Country': 'ES',
#   'Current Description': 'clear sky'},
#  {'City': 'Nouadhibou',
#   'Lat': 20.931,
#   'Lng': -17.0347,
#   'Max Temp': 69.78,
#   'Humidity': 78,
#   'Cloudiness': 100,
#   'Wind Speed': 14.97,
#   'Country': 'MR',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Tiksi',
#   'Lat': 71.6872,
#   'Lng': 128.8694,
#   'Max Temp': -3.77,
#   'Humidity': 100,
#   'Cloudiness': 100,
#   'Wind Speed': 2.73,
#   'Country': 'RU',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Mandalgovi',
#   'Lat': 45.7625,
#   'Lng': 106.2708,
#   'Max Temp': 44.53,
#   'Humidity': 34,
#   'Cloudiness': 0,
#   'Wind Speed': 15.48,
#   'Country': 'MN',
#   'Current Description': 'clear sky'},
#  {'City': 'Codo',
#   'Lat': -4.4553,
#   'Lng': -43.8856,
#   'Max Temp': 82.42,
#   'Humidity': 89,
#   'Cloudiness': 85,
#   'Wind Speed': 2.04,
#   'Country': 'BR',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Belaya Gora',
#   'Lat': 68.5333,
#   'Lng': 146.4167,
#   'Max Temp': -3.57,
#   'Humidity': 100,
#   'Cloudiness': 100,
#   'Wind Speed': 3.13,
#   'Country': 'RU',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Hermanus',
#   'Lat': -34.4187,
#   'Lng': 19.2345,
#   'Max Temp': 61.81,
#   'Humidity': 88,
#   'Cloudiness': 3,
#   'Wind Speed': 9.8,
#   'Country': 'ZA',
#   'Current Description': 'clear sky'},
#  {'City': 'Chachoengsao',
#   'Lat': 13.6167,
#   'Lng': 101.4167,
#   'Max Temp': 82.92,
#   'Humidity': 84,
#   'Cloudiness': 100,
#   'Wind Speed': 2.04,
#   'Country': 'TH',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Butaritari',
#   'Lat': 3.0707,
#   'Lng': 172.7902,
#   'Max Temp': 81.43,
#   'Humidity': 75,
#   'Cloudiness': 26,
#   'Wind Speed': 12.37,
#   'Country': 'KI',
#   'Current Description': 'scattered clouds'},
#  {'City': 'Mataura',
#   'Lat': -46.1927,
#   'Lng': 168.8643,
#   'Max Temp': 46.63,
#   'Humidity': 89,
#   'Cloudiness': 100,
#   'Wind Speed': 3.29,
#   'Country': 'NZ',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Qaanaaq',
#   'Lat': 77.484,
#   'Lng': -69.3632,
#   'Max Temp': -7.92,
#   'Humidity': 80,
#   'Cloudiness': 9,
#   'Wind Speed': 1.68,
#   'Country': 'GL',
#   'Current Description': 'clear sky'},
#  {'City': 'Chokurdakh',
#   'Lat': 70.6333,
#   'Lng': 147.9167,
#   'Max Temp': -5.98,
#   'Humidity': 100,
#   'Cloudiness': 64,
#   'Wind Speed': 4.23,
#   'Country': 'RU',
#   'Current Description': 'broken clouds'},
#  {'City': 'Rikitea',
#   'Lat': -23.1203,
#   'Lng': -134.9692,
#   'Max Temp': 78.39,
#   'Humidity': 66,
#   'Cloudiness': 6,
#   'Wind Speed': 14.54,
#   'Country': 'PF',
#   'Current Description': 'clear sky'},
#  {'City': 'Pierre',
#   'Lat': 44.3683,
#   'Lng': -100.351,
#   'Max Temp': 48.85,
#   'Humidity': 33,
#   'Cloudiness': 0,
#   'Wind Speed': 8.05,
#   'Country': 'US',
#   'Current Description': 'clear sky'},
#  {'City': 'Sovetskaya',
#   'Lat': 44.7769,
#   'Lng': 41.1722,
#   'Max Temp': 62.73,
#   'Humidity': 67,
#   'Cloudiness': 100,
#   'Wind Speed': 7.67,
#   'Country': 'RU',
#   'Current Description': 'light rain'},
#  {'City': 'Tuatapere',
#   'Lat': -46.1333,
#   'Lng': 167.6833,
#   'Max Temp': 53.67,
#   'Humidity': 87,
#   'Cloudiness': 100,
#   'Wind Speed': 5.61,
#   'Country': 'NZ',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Katsuura',
#   'Lat': 35.1333,
#   'Lng': 140.3,
#   'Max Temp': 56.57,
#   'Humidity': 87,
#   'Cloudiness': 100,
#   'Wind Speed': 12.57,
#   'Country': 'JP',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Shubarshi',
#   'Lat': 48.5872,
#   'Lng': 57.1869,
#   'Max Temp': 58.03,
#   'Humidity': 46,
#   'Cloudiness': 100,
#   'Wind Speed': 5.39,
#   'Country': 'KZ',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Bathsheba',
#   'Lat': 13.2167,
#   'Lng': -59.5167,
#   'Max Temp': 84.81,
#   'Humidity': 65,
#   'Cloudiness': 40,
#   'Wind Speed': 19.57,
#   'Country': 'BB',
#   'Current Description': 'scattered clouds'},
#  {'City': 'Hokitika',
#   'Lat': -42.7167,
#   'Lng': 170.9667,
#   'Max Temp': 53.13,
#   'Humidity': 71,
#   'Cloudiness': 100,
#   'Wind Speed': 4.83,
#   'Country': 'NZ',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Nanortalik',
#   'Lat': 60.1432,
#   'Lng': -45.2371,
#   'Max Temp': 35.01,
#   'Humidity': 74,
#   'Cloudiness': 100,
#   'Wind Speed': 1.99,
#   'Country': 'GL',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Katherine',
#   'Lat': -14.4667,
#   'Lng': 132.2667,
#   'Max Temp': 73.72,
#   'Humidity': 73,
#   'Cloudiness': 48,
#   'Wind Speed': 0,
#   'Country': 'AU',
#   'Current Description': 'scattered clouds'},
#  {'City': 'Khatanga',
#   'Lat': 71.9667,
#   'Lng': 102.5,
#   'Max Temp': 0.59,
#   'Humidity': 98,
#   'Cloudiness': 95,
#   'Wind Speed': 8.48,
#   'Country': 'RU',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Palmer',
#   'Lat': 42.1584,
#   'Lng': -72.3287,
#   'Max Temp': 59.77,
#   'Humidity': 24,
#   'Cloudiness': 75,
#   'Wind Speed': 7,
#   'Country': 'US',
#   'Current Description': 'broken clouds'},
#  {'City': 'Ilulissat',
#   'Lat': 69.2167,
#   'Lng': -51.1,
#   'Max Temp': 15.82,
#   'Humidity': 79,
#   'Cloudiness': 100,
#   'Wind Speed': 12.66,
#   'Country': 'GL',
#   'Current Description': 'light shower snow'},
#  {'City': 'Merced',
#   'Lat': 37.1666,
#   'Lng': -120.7516,
#   'Max Temp': 66.54,
#   'Humidity': 40,
#   'Cloudiness': 29,
#   'Wind Speed': 7.07,
#   'Country': 'US',
#   'Current Description': 'scattered clouds'},
#  {'City': 'Tura',
#   'Lat': 25.5198,
#   'Lng': 90.2201,
#   'Max Temp': 70.61,
#   'Humidity': 87,
#   'Cloudiness': 0,
#   'Wind Speed': 4.21,
#   'Country': 'IN',
#   'Current Description': 'clear sky'},
#  {'City': 'Norman Wells',
#   'Lat': 65.282,
#   'Lng': -126.8329,
#   'Max Temp': 17.64,
#   'Humidity': 41,
#   'Cloudiness': 0,
#   'Wind Speed': 9.22,
#   'Country': 'CA',
#   'Current Description': 'clear sky'},
#  {'City': 'Avarua',
#   'Lat': -21.2078,
#   'Lng': -159.775,
#   'Max Temp': 73.45,
#   'Humidity': 94,
#   'Cloudiness': 100,
#   'Wind Speed': 2.3,
#   'Country': 'CK',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Berlevag',
#   'Lat': 70.8578,
#   'Lng': 29.0864,
#   'Max Temp': 42.6,
#   'Humidity': 96,
#   'Cloudiness': 100,
#   'Wind Speed': 26.57,
#   'Country': 'NO',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Osakarovka',
#   'Lat': 50.565,
#   'Lng': 72.5692,
#   'Max Temp': 41.41,
#   'Humidity': 83,
#   'Cloudiness': 100,
#   'Wind Speed': 13.49,
#   'Country': 'KZ',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Hilo',
#   'Lat': 19.7297,
#   'Lng': -155.09,
#   'Max Temp': 77.29,
#   'Humidity': 91,
#   'Cloudiness': 100,
#   'Wind Speed': 5.75,
#   'Country': 'US',
#   'Current Description': 'heavy intensity rain'},
#  {'City': 'Longyearbyen',
#   'Lat': 78.2186,
#   'Lng': 15.6401,
#   'Max Temp': 15.64,
#   'Humidity': 73,
#   'Cloudiness': 20,
#   'Wind Speed': 3.44,
#   'Country': 'SJ',
#   'Current Description': 'few clouds'},
#  {'City': 'San Quintin',
#   'Lat': 30.4833,
#   'Lng': -115.95,
#   'Max Temp': 67.77,
#   'Humidity': 65,
#   'Cloudiness': 6,
#   'Wind Speed': 19.73,
#   'Country': 'MX',
#   'Current Description': 'clear sky'},
#  {'City': 'Saint Anthony',
#   'Lat': 45.0205,
#   'Lng': -93.218,
#   'Max Temp': 37.24,
#   'Humidity': 71,
#   'Cloudiness': 100,
#   'Wind Speed': 23.02,
#   'Country': 'US',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Ahipara',
#   'Lat': -35.1667,
#   'Lng': 173.1667,
#   'Max Temp': 65.5,
#   'Humidity': 95,
#   'Cloudiness': 39,
#   'Wind Speed': 6.08,
#   'Country': 'NZ',
#   'Current Description': 'scattered clouds'},
#  {'City': 'Saskylakh',
#   'Lat': 71.9167,
#   'Lng': 114.0833,
#   'Max Temp': 11.5,
#   'Humidity': 94,
#   'Cloudiness': 100,
#   'Wind Speed': 14.76,
#   'Country': 'RU',
#   'Current Description': 'light snow'},
#  {'City': 'Kruisfontein',
#   'Lat': -34.0033,
#   'Lng': 24.7314,
#   'Max Temp': 60.89,
#   'Humidity': 90,
#   'Cloudiness': 7,
#   'Wind Speed': 3,
#   'Country': 'ZA',
#   'Current Description': 'clear sky'},
#  {'City': 'Kuhdasht',
#   'Lat': 33.535,
#   'Lng': 47.6061,
#   'Max Temp': 60.55,
#   'Humidity': 20,
#   'Cloudiness': 76,
#   'Wind Speed': 4.03,
#   'Country': 'IR',
#   'Current Description': 'broken clouds'},
#  {'City': 'Saint-Philippe',
#   'Lat': -21.3585,
#   'Lng': 55.7679,
#   'Max Temp': 78.39,
#   'Humidity': 88,
#   'Cloudiness': 22,
#   'Wind Speed': 11.18,
#   'Country': 'RE',
#   'Current Description': 'few clouds'},
#  {'City': 'Vanimo',
#   'Lat': -2.6741,
#   'Lng': 141.3028,
#   'Max Temp': 77.72,
#   'Humidity': 87,
#   'Cloudiness': 100,
#   'Wind Speed': 2.33,
#   'Country': 'PG',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Mumford',
#   'Lat': 5.2618,
#   'Lng': -0.759,
#   'Max Temp': 78.57,
#   'Humidity': 80,
#   'Cloudiness': 100,
#   'Wind Speed': 5.14,
#   'Country': 'GH',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Bambous Virieux',
#   'Lat': -20.3428,
#   'Lng': 57.7575,
#   'Max Temp': 79.21,
#   'Humidity': 94,
#   'Cloudiness': 40,
#   'Wind Speed': 10.36,
#   'Country': 'MU',
#   'Current Description': 'scattered clouds'},
#  {'City': 'Umm Kaddadah',
#   'Lat': 13.6017,
#   'Lng': 26.6876,
#   'Max Temp': 90.12,
#   'Humidity': 27,
#   'Cloudiness': 81,
#   'Wind Speed': 1.45,
#   'Country': 'SD',
#   'Current Description': 'broken clouds'},
#  {'City': 'Severo-Kurilsk',
#   'Lat': 50.6789,
#   'Lng': 156.125,
#   'Max Temp': 28.71,
#   'Humidity': 90,
#   'Cloudiness': 76,
#   'Wind Speed': 5.03,
#   'Country': 'RU',
#   'Current Description': 'broken clouds'},
#  {'City': 'Cockburn Town',
#   'Lat': 21.4612,
#   'Lng': -71.1419,
#   'Max Temp': 82.36,
#   'Humidity': 65,
#   'Cloudiness': 40,
#   'Wind Speed': 16.11,
#   'Country': 'TC',
#   'Current Description': 'scattered clouds'},
#  {'City': 'Evensk',
#   'Lat': 61.95,
#   'Lng': 159.2333,
#   'Max Temp': 23.04,
#   'Humidity': 96,
#   'Cloudiness': 100,
#   'Wind Speed': 3.49,
#   'Country': 'RU',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Salalah',
#   'Lat': 17.0151,
#   'Lng': 54.0924,
#   'Max Temp': 84.29,
#   'Humidity': 79,
#   'Cloudiness': 75,
#   'Wind Speed': 6.91,
#   'Country': 'OM',
#   'Current Description': 'broken clouds'},
#  {'City': 'Bahar',
#   'Lat': 34.9072,
#   'Lng': 48.4414,
#   'Max Temp': 46.56,
#   'Humidity': 31,
#   'Cloudiness': 0,
#   'Wind Speed': 2.3,
#   'Country': 'IR',
#   'Current Description': 'clear sky'},
#  {'City': 'Atuona',
#   'Lat': -9.8,
#   'Lng': -139.0333,
#   'Max Temp': 80.04,
#   'Humidity': 70,
#   'Cloudiness': 95,
#   'Wind Speed': 17.13,
#   'Country': 'PF',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Pacific Grove',
#   'Lat': 36.6177,
#   'Lng': -121.9166,
#   'Max Temp': 63.39,
#   'Humidity': 60,
#   'Cloudiness': 0,
#   'Wind Speed': 5.75,
#   'Country': 'US',
#   'Current Description': 'clear sky'},
#  {'City': 'Mar Del Plata',
#   'Lat': -38.0023,
#   'Lng': -57.5575,
#   'Max Temp': 64.42,
#   'Humidity': 92,
#   'Cloudiness': 40,
#   'Wind Speed': 20,
#   'Country': 'AR',
#   'Current Description': 'scattered clouds'},
#  {'City': 'Sandusky',
#   'Lat': 41.3501,
#   'Lng': -83.1332,
#   'Max Temp': 35.56,
#   'Humidity': 85,
#   'Cloudiness': 100,
#   'Wind Speed': 3,
#   'Country': 'US',
#   'Current Description': 'snow'},
#  {'City': 'Quatre Cocos',
#   'Lat': -20.2078,
#   'Lng': 57.7625,
#   'Max Temp': 79.09,
#   'Humidity': 85,
#   'Cloudiness': 28,
#   'Wind Speed': 11.12,
#   'Country': 'MU',
#   'Current Description': 'scattered clouds'},
#  {'City': 'Ribeira Grande',
#   'Lat': 38.5167,
#   'Lng': -28.7,
#   'Max Temp': 61.2,
#   'Humidity': 63,
#   'Cloudiness': 75,
#   'Wind Speed': 14.97,
#   'Country': 'PT',
#   'Current Description': 'broken clouds'},
#  {'City': 'Mehamn',
#   'Lat': 71.0357,
#   'Lng': 27.8492,
#   'Max Temp': 40.98,
#   'Humidity': 98,
#   'Cloudiness': 100,
#   'Wind Speed': 26.31,
#   'Country': 'NO',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Mareeba',
#   'Lat': -17,
#   'Lng': 145.4333,
#   'Max Temp': 68.72,
#   'Humidity': 93,
#   'Cloudiness': 100,
#   'Wind Speed': 2.08,
#   'Country': 'AU',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Lorengau',
#   'Lat': -2.0226,
#   'Lng': 147.2712,
#   'Max Temp': 82.36,
#   'Humidity': 73,
#   'Cloudiness': 100,
#   'Wind Speed': 7.31,
#   'Country': 'PG',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Vaini',
#   'Lat': -21.2,
#   'Lng': -175.2,
#   'Max Temp': 77.16,
#   'Humidity': 94,
#   'Cloudiness': 75,
#   'Wind Speed': 3.44,
#   'Country': 'TO',
#   'Current Description': 'broken clouds'},
#  {'City': 'Port Elizabeth',
#   'Lat': -33.918,
#   'Lng': 25.5701,
#   'Max Temp': 63.1,
#   'Humidity': 92,
#   'Cloudiness': 0,
#   'Wind Speed': 3.44,
#   'Country': 'ZA',
#   'Current Description': 'clear sky'},
#  {'City': 'Kavaratti',
#   'Lat': 10.5669,
#   'Lng': 72.642,
#   'Max Temp': 84.22,
#   'Humidity': 74,
#   'Cloudiness': 97,
#   'Wind Speed': 6.6,
#   'Country': 'IN',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Port Hedland',
#   'Lat': -20.3167,
#   'Lng': 118.5667,
#   'Max Temp': 82.45,
#   'Humidity': 36,
#   'Cloudiness': 37,
#   'Wind Speed': 8.05,
#   'Country': 'AU',
#   'Current Description': 'scattered clouds'},
#  {'City': 'Tasiilaq',
#   'Lat': 65.6145,
#   'Lng': -37.6368,
#   'Max Temp': 33.96,
#   'Humidity': 97,
#   'Cloudiness': 100,
#   'Wind Speed': 5.99,
#   'Country': 'GL',
#   'Current Description': 'light snow'},
#  {'City': 'Puerto Ayora',
#   'Lat': -0.7393,
#   'Lng': -90.3518,
#   'Max Temp': 78.76,
#   'Humidity': 82,
#   'Cloudiness': 83,
#   'Wind Speed': 8.37,
#   'Country': 'EC',
#   'Current Description': 'broken clouds'},
#  {'City': 'Carnarvon',
#   'Lat': -24.8667,
#   'Lng': 113.6333,
#   'Max Temp': 68.07,
#   'Humidity': 77,
#   'Cloudiness': 24,
#   'Wind Speed': 10.36,
#   'Country': 'AU',
#   'Current Description': 'few clouds'},
#  {'City': 'Kapaa',
#   'Lat': 22.0752,
#   'Lng': -159.319,
#   'Max Temp': 75.18,
#   'Humidity': 70,
#   'Cloudiness': 20,
#   'Wind Speed': 19.57,
#   'Country': 'US',
#   'Current Description': 'few clouds'},
#  {'City': 'Hinton',
#   'Lat': 53.4001,
#   'Lng': -117.5857,
#   'Max Temp': 36,
#   'Humidity': 61,
#   'Cloudiness': 100,
#   'Wind Speed': 6.82,
#   'Country': 'CA',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Jamestown',
#   'Lat': 42.097,
#   'Lng': -79.2353,
#   'Max Temp': 38.52,
#   'Humidity': 63,
#   'Cloudiness': 100,
#   'Wind Speed': 17.27,
#   'Country': 'US',
#   'Current Description': 'light snow'},
#  {'City': 'Chicama',
#   'Lat': -7.8447,
#   'Lng': -79.1469,
#   'Max Temp': 63.14,
#   'Humidity': 61,
#   'Cloudiness': 51,
#   'Wind Speed': 10.63,
#   'Country': 'PE',
#   'Current Description': 'broken clouds'},
#  {'City': 'Punta Arenas',
#   'Lat': -53.15,
#   'Lng': -70.9167,
#   'Max Temp': 51.91,
#   'Humidity': 62,
#   'Cloudiness': 75,
#   'Wind Speed': 10.36,
#   'Country': 'CL',
#   'Current Description': 'broken clouds'},
#  {'City': 'New Norfolk',
#   'Lat': -42.7826,
#   'Lng': 147.0587,
#   'Max Temp': 52.72,
#   'Humidity': 67,
#   'Cloudiness': 100,
#   'Wind Speed': 1.77,
#   'Country': 'AU',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Eureka',
#   'Lat': 40.8021,
#   'Lng': -124.1637,
#   'Max Temp': 57.36,
#   'Humidity': 71,
#   'Cloudiness': 100,
#   'Wind Speed': 10,
#   'Country': 'US',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Sao Joao Da Barra',
#   'Lat': -21.6403,
#   'Lng': -41.0511,
#   'Max Temp': 80.69,
#   'Humidity': 66,
#   'Cloudiness': 27,
#   'Wind Speed': 13.47,
#   'Country': 'BR',
#   'Current Description': 'scattered clouds'},
#  {'City': 'Jeremie',
#   'Lat': 18.65,
#   'Lng': -74.1167,
#   'Max Temp': 80.55,
#   'Humidity': 74,
#   'Cloudiness': 34,
#   'Wind Speed': 3.15,
#   'Country': 'HT',
#   'Current Description': 'scattered clouds'},
#  {'City': 'Vangaindrano',
#   'Lat': -23.35,
#   'Lng': 47.6,
#   'Max Temp': 74.66,
#   'Humidity': 88,
#   'Cloudiness': 98,
#   'Wind Speed': 5.7,
#   'Country': 'MG',
#   'Current Description': 'light rain'},
#  {'City': 'Komsomolskiy',
#   'Lat': 40.4272,
#   'Lng': 71.7189,
#   'Max Temp': 70.52,
#   'Humidity': 46,
#   'Cloudiness': 86,
#   'Wind Speed': 2.3,
#   'Country': 'UZ',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Upernavik',
#   'Lat': 72.7868,
#   'Lng': -56.1549,
#   'Max Temp': 7.57,
#   'Humidity': 91,
#   'Cloudiness': 100,
#   'Wind Speed': 1.79,
#   'Country': 'GL',
#   'Current Description': 'light snow'},
#  {'City': 'Manoel Urbano',
#   'Lat': -8.8389,
#   'Lng': -69.2597,
#   'Max Temp': 84.99,
#   'Humidity': 57,
#   'Cloudiness': 85,
#   'Wind Speed': 5.21,
#   'Country': 'BR',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Fortuna',
#   'Lat': 40.5982,
#   'Lng': -124.1573,
#   'Max Temp': 57.09,
#   'Humidity': 81,
#   'Cloudiness': 100,
#   'Wind Speed': 23.02,
#   'Country': 'US',
#   'Current Description': 'light rain'},
#  {'City': 'Souillac',
#   'Lat': -20.5167,
#   'Lng': 57.5167,
#   'Max Temp': 79.18,
#   'Humidity': 94,
#   'Cloudiness': 40,
#   'Wind Speed': 10.36,
#   'Country': 'MU',
#   'Current Description': 'scattered clouds'},
#  {'City': 'Aklavik',
#   'Lat': 68.2191,
#   'Lng': -135.0107,
#   'Max Temp': 15.8,
#   'Humidity': 48,
#   'Cloudiness': 0,
#   'Wind Speed': 6.91,
#   'Country': 'CA',
#   'Current Description': 'clear sky'},
#  {'City': 'Dodge City',
#   'Lat': 37.7528,
#   'Lng': -100.0171,
#   'Max Temp': 56.25,
#   'Humidity': 39,
#   'Cloudiness': 40,
#   'Wind Speed': 5.01,
#   'Country': 'US',
#   'Current Description': 'scattered clouds'},
#  {'City': 'Umm Lajj',
#   'Lat': 25.0213,
#   'Lng': 37.2685,
#   'Max Temp': 85.87,
#   'Humidity': 35,
#   'Cloudiness': 97,
#   'Wind Speed': 3.18,
#   'Country': 'SA',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Dwarka',
#   'Lat': 22.2394,
#   'Lng': 68.9678,
#   'Max Temp': 80.62,
#   'Humidity': 78,
#   'Cloudiness': 5,
#   'Wind Speed': 12.08,
#   'Country': 'IN',
#   'Current Description': 'clear sky'},
#  {'City': 'Tuktoyaktuk',
#   'Lat': 69.4541,
#   'Lng': -133.0374,
#   'Max Temp': 8.6,
#   'Humidity': 66,
#   'Cloudiness': 0,
#   'Wind Speed': 6.91,
#   'Country': 'CA',
#   'Current Description': 'clear sky'},
#  {'City': 'Dunedin',
#   'Lat': -45.8742,
#   'Lng': 170.5036,
#   'Max Temp': 52.81,
#   'Humidity': 85,
#   'Cloudiness': 91,
#   'Wind Speed': 4.99,
#   'Country': 'NZ',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Belyy Yar',
#   'Lat': 53.6039,
#   'Lng': 91.3903,
#   'Max Temp': 48.09,
#   'Humidity': 46,
#   'Cloudiness': 0,
#   'Wind Speed': 8.95,
#   'Country': 'RU',
#   'Current Description': 'light rain'},
#  {'City': 'Dikson',
#   'Lat': 73.5069,
#   'Lng': 80.5464,
#   'Max Temp': 2.35,
#   'Humidity': 94,
#   'Cloudiness': 100,
#   'Wind Speed': 13.27,
#   'Country': 'RU',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Mathbaria',
#   'Lat': 22.2876,
#   'Lng': 89.9593,
#   'Max Temp': 79.05,
#   'Humidity': 90,
#   'Cloudiness': 25,
#   'Wind Speed': 4.07,
#   'Country': 'BD',
#   'Current Description': 'scattered clouds'},
#  {'City': 'Isangel',
#   'Lat': -19.55,
#   'Lng': 169.2667,
#   'Max Temp': 78.3,
#   'Humidity': 86,
#   'Cloudiness': 100,
#   'Wind Speed': 5.1,
#   'Country': 'VU',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Castro',
#   'Lat': -24.7911,
#   'Lng': -50.0119,
#   'Max Temp': 67.62,
#   'Humidity': 57,
#   'Cloudiness': 43,
#   'Wind Speed': 3.18,
#   'Country': 'BR',
#   'Current Description': 'scattered clouds'},
#  {'City': 'Torbay',
#   'Lat': 47.6666,
#   'Lng': -52.7314,
#   'Max Temp': 45.39,
#   'Humidity': 63,
#   'Cloudiness': 40,
#   'Wind Speed': 27.63,
#   'Country': 'CA',
#   'Current Description': 'scattered clouds'},
#  {'City': 'San Juan',
#   'Lat': -31.5375,
#   'Lng': -68.5364,
#   'Max Temp': 81.23,
#   'Humidity': 22,
#   'Cloudiness': 0,
#   'Wind Speed': 5.99,
#   'Country': 'AR',
#   'Current Description': 'clear sky'},
#  {'City': 'Albany',
#   'Lat': 42.6001,
#   'Lng': -73.9662,
#   'Max Temp': 57.92,
#   'Humidity': 31,
#   'Cloudiness': 50,
#   'Wind Speed': 3,
#   'Country': 'US',
#   'Current Description': 'scattered clouds'},
#  {'City': 'Khani',
#   'Lat': 41.9563,
#   'Lng': 42.9566,
#   'Max Temp': 67.57,
#   'Humidity': 62,
#   'Cloudiness': 58,
#   'Wind Speed': 9.37,
#   'Country': 'GE',
#   'Current Description': 'broken clouds'},
#  {'City': 'Lensk',
#   'Lat': 60.7253,
#   'Lng': 114.9278,
#   'Max Temp': 25.34,
#   'Humidity': 84,
#   'Cloudiness': 100,
#   'Wind Speed': 13.18,
#   'Country': 'RU',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Ancud',
#   'Lat': -41.8697,
#   'Lng': -73.8203,
#   'Max Temp': 55.22,
#   'Humidity': 69,
#   'Cloudiness': 86,
#   'Wind Speed': 6.11,
#   'Country': 'CL',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Safford',
#   'Lat': 32.834,
#   'Lng': -109.7076,
#   'Max Temp': 84.11,
#   'Humidity': 5,
#   'Cloudiness': 1,
#   'Wind Speed': 8.46,
#   'Country': 'US',
#   'Current Description': 'clear sky'},
#  {'City': 'Paamiut',
#   'Lat': 61.994,
#   'Lng': -49.6678,
#   'Max Temp': 27.37,
#   'Humidity': 78,
#   'Cloudiness': 100,
#   'Wind Speed': 26.13,
#   'Country': 'GL',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Severnoye',
#   'Lat': 56.3491,
#   'Lng': 78.3619,
#   'Max Temp': 32.4,
#   'Humidity': 78,
#   'Cloudiness': 43,
#   'Wind Speed': 6.51,
#   'Country': 'RU',
#   'Current Description': 'scattered clouds'},
#  {'City': 'Angers',
#   'Lat': 47.4667,
#   'Lng': -0.55,
#   'Max Temp': 60.82,
#   'Humidity': 67,
#   'Cloudiness': 100,
#   'Wind Speed': 10.76,
#   'Country': 'FR',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Wanlaweyn',
#   'Lat': 2.6185,
#   'Lng': 44.8938,
#   'Max Temp': 82.62,
#   'Humidity': 72,
#   'Cloudiness': 100,
#   'Wind Speed': 12.46,
#   'Country': 'SO',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Saurimo',
#   'Lat': -9.6608,
#   'Lng': 20.3916,
#   'Max Temp': 67.33,
#   'Humidity': 94,
#   'Cloudiness': 96,
#   'Wind Speed': 3.65,
#   'Country': 'AO',
#   'Current Description': 'moderate rain'},
#  {'City': 'Namatanai',
#   'Lat': -3.6667,
#   'Lng': 152.4333,
#   'Max Temp': 80.4,
#   'Humidity': 80,
#   'Cloudiness': 100,
#   'Wind Speed': 9.22,
#   'Country': 'PG',
#   'Current Description': 'light rain'},
#  {'City': 'Iqaluit',
#   'Lat': 63.7506,
#   'Lng': -68.5145,
#   'Max Temp': -0.31,
#   'Humidity': 70,
#   'Cloudiness': 100,
#   'Wind Speed': 3.44,
#   'Country': 'CA',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Aljezur',
#   'Lat': 37.3191,
#   'Lng': -8.8033,
#   'Max Temp': 58.3,
#   'Humidity': 76,
#   'Cloudiness': 0,
#   'Wind Speed': 22.5,
#   'Country': 'PT',
#   'Current Description': 'clear sky'},
#  {'City': 'Lanxi',
#   'Lat': 29.2195,
#   'Lng': 119.477,
#   'Max Temp': 52.45,
#   'Humidity': 96,
#   'Cloudiness': 100,
#   'Wind Speed': 1.25,
#   'Country': 'CN',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Port Alfred',
#   'Lat': -33.5906,
#   'Lng': 26.891,
#   'Max Temp': 60.19,
#   'Humidity': 95,
#   'Cloudiness': 46,
#   'Wind Speed': 2.28,
#   'Country': 'ZA',
#   'Current Description': 'scattered clouds'},
#  {'City': 'San Cristobal',
#   'Lat': 7.7669,
#   'Lng': -72.225,
#   'Max Temp': 78.98,
#   'Humidity': 56,
#   'Cloudiness': 96,
#   'Wind Speed': 5.93,
#   'Country': 'VE',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Nikolskoye',
#   'Lat': 59.7035,
#   'Lng': 30.7861,
#   'Max Temp': 46.29,
#   'Humidity': 87,
#   'Cloudiness': 89,
#   'Wind Speed': 3.18,
#   'Country': 'RU',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Nieuw Amsterdam',
#   'Lat': 5.8833,
#   'Lng': -55.0833,
#   'Max Temp': 82.56,
#   'Humidity': 79,
#   'Cloudiness': 20,
#   'Wind Speed': 6.91,
#   'Country': 'SR',
#   'Current Description': 'few clouds'},
#  {'City': 'Guerrero Negro',
#   'Lat': 27.9769,
#   'Lng': -114.0611,
#   'Max Temp': 69.89,
#   'Humidity': 59,
#   'Cloudiness': 80,
#   'Wind Speed': 16.26,
#   'Country': 'MX',
#   'Current Description': 'broken clouds'},
#  {'City': 'Port Lincoln',
#   'Lat': -34.7333,
#   'Lng': 135.8667,
#   'Max Temp': 58.08,
#   'Humidity': 65,
#   'Cloudiness': 45,
#   'Wind Speed': 10.83,
#   'Country': 'AU',
#   'Current Description': 'scattered clouds'},
#  {'City': 'Fort Nelson',
#   'Lat': 58.8053,
#   'Lng': -122.7002,
#   'Max Temp': 20.79,
#   'Humidity': 49,
#   'Cloudiness': 40,
#   'Wind Speed': 9.22,
#   'Country': 'CA',
#   'Current Description': 'scattered clouds'},
#  {'City': 'Bredasdorp',
#   'Lat': -34.5322,
#   'Lng': 20.0403,
#   'Max Temp': 60.53,
#   'Humidity': 94,
#   'Cloudiness': 3,
#   'Wind Speed': 7.29,
#   'Country': 'ZA',
#   'Current Description': 'clear sky'},
#  {'City': 'Bilma',
#   'Lat': 18.6853,
#   'Lng': 12.9164,
#   'Max Temp': 84.99,
#   'Humidity': 14,
#   'Cloudiness': 24,
#   'Wind Speed': 10.98,
#   'Country': 'NE',
#   'Current Description': 'few clouds'},
#  {'City': 'Kodiak',
#   'Lat': 57.79,
#   'Lng': -152.4072,
#   'Max Temp': 38.71,
#   'Humidity': 70,
#   'Cloudiness': 100,
#   'Wind Speed': 11.5,
#   'Country': 'US',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Inta',
#   'Lat': 66.0317,
#   'Lng': 60.1659,
#   'Max Temp': 28.62,
#   'Humidity': 96,
#   'Cloudiness': 99,
#   'Wind Speed': 11.74,
#   'Country': 'RU',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Otane',
#   'Lat': -39.8833,
#   'Lng': 176.6333,
#   'Max Temp': 57,
#   'Humidity': 98,
#   'Cloudiness': 70,
#   'Wind Speed': 4.03,
#   'Country': 'NZ',
#   'Current Description': 'broken clouds'},
#  {'City': 'Vestmannaeyjar',
#   'Lat': 63.4427,
#   'Lng': -20.2734,
#   'Max Temp': 47.39,
#   'Humidity': 71,
#   'Cloudiness': 0,
#   'Wind Speed': 20.71,
#   'Country': 'IS',
#   'Current Description': 'clear sky'},
#  {'City': 'East London',
#   'Lat': -33.0153,
#   'Lng': 27.9116,
#   'Max Temp': 65.34,
#   'Humidity': 94,
#   'Cloudiness': 100,
#   'Wind Speed': 10.36,
#   'Country': 'ZA',
#   'Current Description': 'light rain'},
#  {'City': 'Camacha',
#   'Lat': 33.0833,
#   'Lng': -16.3333,
#   'Max Temp': 60.22,
#   'Humidity': 72,
#   'Cloudiness': 75,
#   'Wind Speed': 16.11,
#   'Country': 'PT',
#   'Current Description': 'broken clouds'},
#  {'City': 'Batsfjord',
#   'Lat': 70.6345,
#   'Lng': 29.7185,
#   'Max Temp': 40.78,
#   'Humidity': 81,
#   'Cloudiness': 100,
#   'Wind Speed': 12.66,
#   'Country': 'NO',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Cidreira',
#   'Lat': -30.1811,
#   'Lng': -50.2056,
#   'Max Temp': 70.99,
#   'Humidity': 67,
#   'Cloudiness': 89,
#   'Wind Speed': 12.26,
#   'Country': 'BR',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Kaitangata',
#   'Lat': -46.2817,
#   'Lng': 169.8464,
#   'Max Temp': 48.9,
#   'Humidity': 77,
#   'Cloudiness': 100,
#   'Wind Speed': 5.41,
#   'Country': 'NZ',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Nepomuk',
#   'Lat': 49.4862,
#   'Lng': 13.5823,
#   'Max Temp': 50.52,
#   'Humidity': 80,
#   'Cloudiness': 95,
#   'Wind Speed': 2.98,
#   'Country': 'CZ',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Touros',
#   'Lat': -5.1989,
#   'Lng': -35.4608,
#   'Max Temp': 84.15,
#   'Humidity': 67,
#   'Cloudiness': 94,
#   'Wind Speed': 11.25,
#   'Country': 'BR',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Hay River',
#   'Lat': 60.8156,
#   'Lng': -115.7999,
#   'Max Temp': 22.98,
#   'Humidity': 42,
#   'Cloudiness': 0,
#   'Wind Speed': 6.91,
#   'Country': 'CA',
#   'Current Description': 'clear sky'},
#  {'City': 'Bluff',
#   'Lat': -46.6,
#   'Lng': 168.3333,
#   'Max Temp': 54.37,
#   'Humidity': 83,
#   'Cloudiness': 100,
#   'Wind Speed': 9.01,
#   'Country': 'NZ',
#   'Current Description': 'light rain'},
#  {'City': 'Newport',
#   'Lat': 51.5877,
#   'Lng': -2.9984,
#   'Max Temp': 55.11,
#   'Humidity': 67,
#   'Cloudiness': 12,
#   'Wind Speed': 9.55,
#   'Country': 'GB',
#   'Current Description': 'few clouds'},
#  {'City': 'Paharpur',
#   'Lat': 32.1038,
#   'Lng': 70.9724,
#   'Max Temp': 86.13,
#   'Humidity': 24,
#   'Cloudiness': 73,
#   'Wind Speed': 7.56,
#   'Country': 'PK',
#   'Current Description': 'broken clouds'},
#  {'City': 'Bengkulu',
#   'Lat': -3.8004,
#   'Lng': 102.2655,
#   'Max Temp': 75.24,
#   'Humidity': 85,
#   'Cloudiness': 100,
#   'Wind Speed': 4.7,
#   'Country': 'ID',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Labuhan',
#   'Lat': -6.8844,
#   'Lng': 112.2051,
#   'Max Temp': 79.48,
#   'Humidity': 88,
#   'Cloudiness': 100,
#   'Wind Speed': 5.88,
#   'Country': 'ID',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Thompson',
#   'Lat': 55.7435,
#   'Lng': -97.8558,
#   'Max Temp': 37.56,
#   'Humidity': 35,
#   'Cloudiness': 40,
#   'Wind Speed': 12.66,
#   'Country': 'CA',
#   'Current Description': 'scattered clouds'},
#  {'City': 'La Asuncion',
#   'Lat': 11.0333,
#   'Lng': -63.8628,
#   'Max Temp': 83.93,
#   'Humidity': 65,
#   'Cloudiness': 100,
#   'Wind Speed': 19.57,
#   'Country': 'VE',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Boyolangu',
#   'Lat': -8.1181,
#   'Lng': 111.8935,
#   'Max Temp': 76.24,
#   'Humidity': 91,
#   'Cloudiness': 100,
#   'Wind Speed': 4.03,
#   'Country': 'ID',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Georgetown',
#   'Lat': 5.4112,
#   'Lng': 100.3354,
#   'Max Temp': 80.53,
#   'Humidity': 93,
#   'Cloudiness': 20,
#   'Wind Speed': 3.44,
#   'Country': 'MY',
#   'Current Description': 'few clouds'},
#  {'City': 'Chapais',
#   'Lat': 49.7834,
#   'Lng': -74.8492,
#   'Max Temp': 31.78,
#   'Humidity': 62,
#   'Cloudiness': 100,
#   'Wind Speed': 4.76,
#   'Country': 'CA',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Kamaishi',
#   'Lat': 39.2667,
#   'Lng': 141.8833,
#   'Max Temp': 45.52,
#   'Humidity': 77,
#   'Cloudiness': 66,
#   'Wind Speed': 10.85,
#   'Country': 'JP',
#   'Current Description': 'broken clouds'},
#  {'City': 'Victoria',
#   'Lat': 22.2855,
#   'Lng': 114.1577,
#   'Max Temp': 70.25,
#   'Humidity': 84,
#   'Cloudiness': 100,
#   'Wind Speed': 5.99,
#   'Country': 'HK',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Codajas',
#   'Lat': -3.8367,
#   'Lng': -62.0569,
#   'Max Temp': 80.11,
#   'Humidity': 89,
#   'Cloudiness': 100,
#   'Wind Speed': 3.6,
#   'Country': 'BR',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Cabo San Lucas',
#   'Lat': 22.8909,
#   'Lng': -109.9124,
#   'Max Temp': 92.61,
#   'Humidity': 39,
#   'Cloudiness': 20,
#   'Wind Speed': 4.61,
#   'Country': 'MX',
#   'Current Description': 'few clouds'},
#  {'City': 'Buta',
#   'Lat': 2.7858,
#   'Lng': 24.73,
#   'Max Temp': 72.5,
#   'Humidity': 91,
#   'Cloudiness': 29,
#   'Wind Speed': 0.81,
#   'Country': 'CD',
#   'Current Description': 'light rain'},
#  {'City': 'Coquimbo',
#   'Lat': -29.9533,
#   'Lng': -71.3436,
#   'Max Temp': 61.25,
#   'Humidity': 75,
#   'Cloudiness': 13,
#   'Wind Speed': 7.11,
#   'Country': 'CL',
#   'Current Description': 'few clouds'},
#  {'City': 'Rudbar',
#   'Lat': 30.15,
#   'Lng': 62.6,
#   'Max Temp': 66.07,
#   'Humidity': 47,
#   'Cloudiness': 96,
#   'Wind Speed': 23,
#   'Country': 'AF',
#   'Current Description': 'light rain'},
#  {'City': 'Ponta Do Sol',
#   'Lat': 32.6667,
#   'Lng': -17.1,
#   'Max Temp': 67.12,
#   'Humidity': 62,
#   'Cloudiness': 13,
#   'Wind Speed': 11.95,
#   'Country': 'PT',
#   'Current Description': 'few clouds'},
#  {'City': 'Mesimerion',
#   'Lat': 40.412,
#   'Lng': 23.0059,
#   'Max Temp': 46.87,
#   'Humidity': 93,
#   'Cloudiness': 100,
#   'Wind Speed': 2.3,
#   'Country': 'GR',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Nicholasville',
#   'Lat': 37.8806,
#   'Lng': -84.573,
#   'Max Temp': 46.56,
#   'Humidity': 78,
#   'Cloudiness': 100,
#   'Wind Speed': 11.5,
#   'Country': 'US',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Hami',
#   'Lat': 42.8,
#   'Lng': 93.45,
#   'Max Temp': 57.36,
#   'Humidity': 14,
#   'Cloudiness': 0,
#   'Wind Speed': 3.11,
#   'Country': 'CN',
#   'Current Description': 'clear sky'},
#  {'City': 'Umea',
#   'Lat': 63.8284,
#   'Lng': 20.2597,
#   'Max Temp': 37.33,
#   'Humidity': 87,
#   'Cloudiness': 0,
#   'Wind Speed': 3.44,
#   'Country': 'SE',
#   'Current Description': 'clear sky'},
#  {'City': 'Kosikha',
#   'Lat': 53.3617,
#   'Lng': 84.5822,
#   'Max Temp': 44.46,
#   'Humidity': 89,
#   'Cloudiness': 100,
#   'Wind Speed': 11.52,
#   'Country': 'RU',
#   'Current Description': 'light rain'},
#  {'City': 'Weiser',
#   'Lat': 44.251,
#   'Lng': -116.9693,
#   'Max Temp': 57.87,
#   'Humidity': 51,
#   'Cloudiness': 100,
#   'Wind Speed': 5.01,
#   'Country': 'US',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Leningradskiy',
#   'Lat': 69.3833,
#   'Lng': 178.4167,
#   'Max Temp': 11.52,
#   'Humidity': 90,
#   'Cloudiness': 99,
#   'Wind Speed': 3.96,
#   'Country': 'RU',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Hasaki',
#   'Lat': 35.7333,
#   'Lng': 140.8333,
#   'Max Temp': 52.2,
#   'Humidity': 78,
#   'Cloudiness': 100,
#   'Wind Speed': 14.9,
#   'Country': 'JP',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Goderich',
#   'Lat': 43.7501,
#   'Lng': -81.7165,
#   'Max Temp': 46.9,
#   'Humidity': 45,
#   'Cloudiness': 100,
#   'Wind Speed': 16.11,
#   'Country': 'CA',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Sribne',
#   'Lat': 50.6638,
#   'Lng': 32.9187,
#   'Max Temp': 39,
#   'Humidity': 89,
#   'Cloudiness': 100,
#   'Wind Speed': 10.58,
#   'Country': 'UA',
#   'Current Description': 'overcast clouds'},
#  {'City': 'San Rafael',
#   'Lat': -34.6177,
#   'Lng': -68.3301,
#   'Max Temp': 77.54,
#   'Humidity': 28,
#   'Cloudiness': 19,
#   'Wind Speed': 14.85,
#   'Country': 'AR',
#   'Current Description': 'few clouds'},
#  {'City': 'Okhotsk',
#   'Lat': 59.3833,
#   'Lng': 143.3,
#   'Max Temp': 20.03,
#   'Humidity': 96,
#   'Cloudiness': 100,
#   'Wind Speed': 6.85,
#   'Country': 'RU',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Gwadar',
#   'Lat': 25.1216,
#   'Lng': 62.3254,
#   'Max Temp': 80.06,
#   'Humidity': 90,
#   'Cloudiness': 72,
#   'Wind Speed': 4.76,
#   'Country': 'PK',
#   'Current Description': 'broken clouds'},
#  {'City': 'Batemans Bay',
#   'Lat': -35.7167,
#   'Lng': 150.1833,
#   'Max Temp': 62.1,
#   'Humidity': 77,
#   'Cloudiness': 100,
#   'Wind Speed': 3.94,
#   'Country': 'AU',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Bethel',
#   'Lat': 41.3712,
#   'Lng': -73.414,
#   'Max Temp': 53.44,
#   'Humidity': 45,
#   'Cloudiness': 0,
#   'Wind Speed': 11.5,
#   'Country': 'US',
#   'Current Description': 'clear sky'},
#  {'City': 'Carlyle',
#   'Lat': 38.6103,
#   'Lng': -89.3726,
#   'Max Temp': 51.12,
#   'Humidity': 66,
#   'Cloudiness': 100,
#   'Wind Speed': 8.01,
#   'Country': 'US',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Watsa',
#   'Lat': 3.0372,
#   'Lng': 29.5355,
#   'Max Temp': 65.25,
#   'Humidity': 95,
#   'Cloudiness': 16,
#   'Wind Speed': 3.31,
#   'Country': 'CD',
#   'Current Description': 'few clouds'},
#  {'City': 'Tommot',
#   'Lat': 58.9564,
#   'Lng': 126.2925,
#   'Max Temp': 36.34,
#   'Humidity': 95,
#   'Cloudiness': 100,
#   'Wind Speed': 10.58,
#   'Country': 'RU',
#   'Current Description': 'light rain'},
#  {'City': 'Tautira',
#   'Lat': -17.7333,
#   'Lng': -149.15,
#   'Max Temp': 80.01,
#   'Humidity': 75,
#   'Cloudiness': 31,
#   'Wind Speed': 8.63,
#   'Country': 'PF',
#   'Current Description': 'scattered clouds'},
#  {'City': 'Port-Gentil',
#   'Lat': -0.7193,
#   'Lng': 8.7815,
#   'Max Temp': 84.16,
#   'Humidity': 79,
#   'Cloudiness': 75,
#   'Wind Speed': 9.22,
#   'Country': 'GA',
#   'Current Description': 'broken clouds'},
#  {'City': 'Olafsvik',
#   'Lat': 64.8945,
#   'Lng': -23.7142,
#   'Max Temp': 42.48,
#   'Humidity': 64,
#   'Cloudiness': 11,
#   'Wind Speed': 7.34,
#   'Country': 'IS',
#   'Current Description': 'few clouds'},
#  {'City': 'Saldanha',
#   'Lat': -33.0117,
#   'Lng': 17.9442,
#   'Max Temp': 64.45,
#   'Humidity': 78,
#   'Cloudiness': 0,
#   'Wind Speed': 9.82,
#   'Country': 'ZA',
#   'Current Description': 'clear sky'},
#  {'City': 'Springdale',
#   'Lat': 36.1867,
#   'Lng': -94.1288,
#   'Max Temp': 58.55,
#   'Humidity': 50,
#   'Cloudiness': 0,
#   'Wind Speed': 13.8,
#   'Country': 'US',
#   'Current Description': 'clear sky'},
#  {'City': 'Sur',
#   'Lat': 22.5667,
#   'Lng': 59.5289,
#   'Max Temp': 84.65,
#   'Humidity': 52,
#   'Cloudiness': 0,
#   'Wind Speed': 5.44,
#   'Country': 'OM',
#   'Current Description': 'clear sky'},
#  {'City': 'Oudtshoorn',
#   'Lat': -33.5907,
#   'Lng': 22.2014,
#   'Max Temp': 55.76,
#   'Humidity': 78,
#   'Cloudiness': 2,
#   'Wind Speed': 3.67,
#   'Country': 'ZA',
#   'Current Description': 'clear sky'},
#  {'City': 'Santarem',
#   'Lat': -2.4431,
#   'Lng': -54.7083,
#   'Max Temp': 84.33,
#   'Humidity': 79,
#   'Cloudiness': 20,
#   'Wind Speed': 5.75,
#   'Country': 'BR',
#   'Current Description': 'light rain'},
#  {'City': 'Araouane',
#   'Lat': 18.9048,
#   'Lng': -3.5265,
#   'Max Temp': 81.01,
#   'Humidity': 9,
#   'Cloudiness': 0,
#   'Wind Speed': 8.84,
#   'Country': 'ML',
#   'Current Description': 'clear sky'},
#  {'City': 'Chuy',
#   'Lat': -33.6971,
#   'Lng': -53.4616,
#   'Max Temp': 70.63,
#   'Humidity': 60,
#   'Cloudiness': 18,
#   'Wind Speed': 11.07,
#   'Country': 'UY',
#   'Current Description': 'few clouds'},
#  {'City': 'Luderitz',
#   'Lat': -26.6481,
#   'Lng': 15.1594,
#   'Max Temp': 77.16,
#   'Humidity': 37,
#   'Cloudiness': 1,
#   'Wind Speed': 11.43,
#   'Country': 'NA',
#   'Current Description': 'clear sky'},
#  {'City': 'Sept-Iles',
#   'Lat': 50.2001,
#   'Lng': -66.3821,
#   'Max Temp': 37.92,
#   'Humidity': 44,
#   'Cloudiness': 20,
#   'Wind Speed': 8.05,
#   'Country': 'CA',
#   'Current Description': 'few clouds'},
#  {'City': 'Yellowknife',
#   'Lat': 62.456,
#   'Lng': -114.3525,
#   'Max Temp': 21.72,
#   'Humidity': 38,
#   'Cloudiness': 75,
#   'Wind Speed': 8.05,
#   'Country': 'CA',
#   'Current Description': 'broken clouds'},
#  {'City': 'Ixtapa',
#   'Lat': 20.7,
#   'Lng': -105.2,
#   'Max Temp': 81.63,
#   'Humidity': 57,
#   'Cloudiness': 0,
#   'Wind Speed': 8.05,
#   'Country': 'MX',
#   'Current Description': 'clear sky'},
#  {'City': 'Salinas',
#   'Lat': 36.6777,
#   'Lng': -121.6555,
#   'Max Temp': 63.82,
#   'Humidity': 49,
#   'Cloudiness': 0,
#   'Wind Speed': 5.75,
#   'Country': 'US',
#   'Current Description': 'clear sky'},
#  {'City': 'Ostrovnoy',
#   'Lat': 68.0531,
#   'Lng': 39.5131,
#   'Max Temp': 36.9,
#   'Humidity': 100,
#   'Cloudiness': 100,
#   'Wind Speed': 14.65,
#   'Country': 'RU',
#   'Current Description': 'light rain'},
#  {'City': 'Townsville',
#   'Lat': -19.25,
#   'Lng': 146.8,
#   'Max Temp': 70.68,
#   'Humidity': 83,
#   'Cloudiness': 6,
#   'Wind Speed': 6.91,
#   'Country': 'AU',
#   'Current Description': 'clear sky'},
#  {'City': 'Lebu',
#   'Lat': -37.6167,
#   'Lng': -73.65,
#   'Max Temp': 57.79,
#   'Humidity': 87,
#   'Cloudiness': 100,
#   'Wind Speed': 5.73,
#   'Country': 'CL',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Iquitos',
#   'Lat': -3.7481,
#   'Lng': -73.2472,
#   'Max Temp': 77.04,
#   'Humidity': 100,
#   'Cloudiness': 75,
#   'Wind Speed': 6.91,
#   'Country': 'PE',
#   'Current Description': 'broken clouds'},
#  {'City': 'Clyde River',
#   'Lat': 70.4692,
#   'Lng': -68.5914,
#   'Max Temp': -7.37,
#   'Humidity': 71,
#   'Cloudiness': 75,
#   'Wind Speed': 2.3,
#   'Country': 'CA',
#   'Current Description': 'broken clouds'},
#  {'City': 'Davila',
#   'Lat': 18.4726,
#   'Lng': 120.5763,
#   'Max Temp': 76.98,
#   'Humidity': 81,
#   'Cloudiness': 34,
#   'Wind Speed': 15.68,
#   'Country': 'PH',
#   'Current Description': 'scattered clouds'},
#  {'City': 'Ulaangom',
#   'Lat': 49.9811,
#   'Lng': 92.0667,
#   'Max Temp': 46.72,
#   'Humidity': 31,
#   'Cloudiness': 100,
#   'Wind Speed': 0.29,
#   'Country': 'MN',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Moree',
#   'Lat': -29.4667,
#   'Lng': 149.85,
#   'Max Temp': 60.82,
#   'Humidity': 77,
#   'Cloudiness': 5,
#   'Wind Speed': 11.5,
#   'Country': 'AU',
#   'Current Description': 'clear sky'},
#  {'City': 'Ridgecrest',
#   'Lat': 35.6225,
#   'Lng': -117.6709,
#   'Max Temp': 84.02,
#   'Humidity': 10,
#   'Cloudiness': 40,
#   'Wind Speed': 10,
#   'Country': 'US',
#   'Current Description': 'scattered clouds'},
#  {'City': 'Coihaique',
#   'Lat': -45.5752,
#   'Lng': -72.0662,
#   'Max Temp': 59.61,
#   'Humidity': 54,
#   'Cloudiness': 40,
#   'Wind Speed': 8.05,
#   'Country': 'CL',
#   'Current Description': 'scattered clouds'},
#  {'City': 'Kavieng',
#   'Lat': -2.5744,
#   'Lng': 150.7967,
#   'Max Temp': 82.83,
#   'Humidity': 73,
#   'Cloudiness': 100,
#   'Wind Speed': 12.35,
#   'Country': 'PG',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Port Blair',
#   'Lat': 11.6667,
#   'Lng': 92.75,
#   'Max Temp': 80.64,
#   'Humidity': 83,
#   'Cloudiness': 20,
#   'Wind Speed': 0,
#   'Country': 'IN',
#   'Current Description': 'mist'},
#  {'City': 'Abu Dhabi',
#   'Lat': 24.4667,
#   'Lng': 54.3667,
#   'Max Temp': 80.62,
#   'Humidity': 43,
#   'Cloudiness': 0,
#   'Wind Speed': 6.91,
#   'Country': 'AE',
#   'Current Description': 'clear sky'},
#  {'City': 'Chingirlau',
#   'Lat': 51.095,
#   'Lng': 54.0814,
#   'Max Temp': 58.33,
#   'Humidity': 53,
#   'Cloudiness': 100,
#   'Wind Speed': 7.2,
#   'Country': 'KZ',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Filadelfia',
#   'Lat': 39.9523,
#   'Lng': -75.1638,
#   'Max Temp': 49.21,
#   'Humidity': 61,
#   'Cloudiness': 100,
#   'Wind Speed': 11.5,
#   'Country': 'US',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Teya',
#   'Lat': 60.3778,
#   'Lng': 92.6267,
#   'Max Temp': 0.97,
#   'Humidity': 100,
#   'Cloudiness': 71,
#   'Wind Speed': 3.4,
#   'Country': 'RU',
#   'Current Description': 'broken clouds'},
#  {'City': 'Eyl',
#   'Lat': 7.9803,
#   'Lng': 49.8164,
#   'Max Temp': 82.45,
#   'Humidity': 80,
#   'Cloudiness': 7,
#   'Wind Speed': 7.56,
#   'Country': 'SO',
#   'Current Description': 'clear sky'},
#  {'City': 'Mnogovershinnyy',
#   'Lat': 53.9353,
#   'Lng': 139.9242,
#   'Max Temp': 18.21,
#   'Humidity': 97,
#   'Cloudiness': 100,
#   'Wind Speed': 5.46,
#   'Country': 'RU',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Saint George',
#   'Lat': 37.1041,
#   'Lng': -113.5841,
#   'Max Temp': 82.63,
#   'Humidity': 13,
#   'Cloudiness': 0,
#   'Wind Speed': 4.61,
#   'Country': 'US',
#   'Current Description': 'clear sky'},
#  {'City': 'Khorixas',
#   'Lat': -20.3667,
#   'Lng': 14.9667,
#   'Max Temp': 83.16,
#   'Humidity': 36,
#   'Cloudiness': 93,
#   'Wind Speed': 5.99,
#   'Country': 'NA',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Srednekolymsk',
#   'Lat': 67.45,
#   'Lng': 153.6833,
#   'Max Temp': 10.72,
#   'Humidity': 98,
#   'Cloudiness': 98,
#   'Wind Speed': 5.53,
#   'Country': 'RU',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Pyapon',
#   'Lat': 16.2833,
#   'Lng': 95.6833,
#   'Max Temp': 81.68,
#   'Humidity': 73,
#   'Cloudiness': 7,
#   'Wind Speed': 5.03,
#   'Country': 'MM',
#   'Current Description': 'clear sky'},
#  {'City': 'Geraldton',
#   'Lat': -28.7667,
#   'Lng': 114.6,
#   'Max Temp': 54.01,
#   'Humidity': 76,
#   'Cloudiness': 0,
#   'Wind Speed': 8.05,
#   'Country': 'AU',
#   'Current Description': 'clear sky'},
#  {'City': 'Itoman',
#   'Lat': 26.1247,
#   'Lng': 127.6694,
#   'Max Temp': 70.57,
#   'Humidity': 70,
#   'Cloudiness': 100,
#   'Wind Speed': 4.61,
#   'Country': 'JP',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Sorland',
#   'Lat': 67.667,
#   'Lng': 12.6934,
#   'Max Temp': 44.46,
#   'Humidity': 89,
#   'Cloudiness': 78,
#   'Wind Speed': 4.03,
#   'Country': 'NO',
#   'Current Description': 'broken clouds'},
#  {'City': 'Longkou',
#   'Lat': 37.6508,
#   'Lng': 120.3286,
#   'Max Temp': 51.24,
#   'Humidity': 57,
#   'Cloudiness': 0,
#   'Wind Speed': 3.87,
#   'Country': 'CN',
#   'Current Description': 'clear sky'},
#  {'City': 'Buala',
#   'Lat': -8.145,
#   'Lng': 159.5921,
#   'Max Temp': 80.26,
#   'Humidity': 81,
#   'Cloudiness': 100,
#   'Wind Speed': 7.23,
#   'Country': 'SB',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Ozernovskiy',
#   'Lat': 51.5,
#   'Lng': 156.5167,
#   'Max Temp': 28.63,
#   'Humidity': 78,
#   'Cloudiness': 99,
#   'Wind Speed': 3.85,
#   'Country': 'RU',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Kingori',
#   'Lat': -3.2833,
#   'Lng': 36.9833,
#   'Max Temp': 67.23,
#   'Humidity': 75,
#   'Cloudiness': 59,
#   'Wind Speed': 1.32,
#   'Country': 'TZ',
#   'Current Description': 'broken clouds'},
#  {'City': 'Chihuahua',
#   'Lat': 28.5,
#   'Lng': -106,
#   'Max Temp': 81.43,
#   'Humidity': 14,
#   'Cloudiness': 100,
#   'Wind Speed': 10.65,
#   'Country': 'MX',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Cape Town',
#   'Lat': -33.9258,
#   'Lng': 18.4232,
#   'Max Temp': 64.9,
#   'Humidity': 83,
#   'Cloudiness': 0,
#   'Wind Speed': 12.66,
#   'Country': 'ZA',
#   'Current Description': 'clear sky'},
#  {'City': 'Puerto Cabezas',
#   'Lat': 14.0351,
#   'Lng': -83.3888,
#   'Max Temp': 89.56,
#   'Humidity': 62,
#   'Cloudiness': 40,
#   'Wind Speed': 6.91,
#   'Country': 'NI',
#   'Current Description': 'scattered clouds'},
#  {'City': 'La Ronge',
#   'Lat': 55.1001,
#   'Lng': -105.2842,
#   'Max Temp': 41.22,
#   'Humidity': 33,
#   'Cloudiness': 100,
#   'Wind Speed': 9.22,
#   'Country': 'CA',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Batagay-Alyta',
#   'Lat': 67.8006,
#   'Lng': 130.4114,
#   'Max Temp': 8.82,
#   'Humidity': 97,
#   'Cloudiness': 100,
#   'Wind Speed': 2.44,
#   'Country': 'RU',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Caraballeda',
#   'Lat': 10.6112,
#   'Lng': -66.8522,
#   'Max Temp': 84.27,
#   'Humidity': 74,
#   'Cloudiness': 75,
#   'Wind Speed': 4.61,
#   'Country': 'VE',
#   'Current Description': 'broken clouds'},
#  {'City': 'Carutapera',
#   'Lat': -1.195,
#   'Lng': -46.02,
#   'Max Temp': 82.31,
#   'Humidity': 75,
#   'Cloudiness': 100,
#   'Wind Speed': 5.08,
#   'Country': 'BR',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Vung Tau',
#   'Lat': 10.346,
#   'Lng': 107.0843,
#   'Max Temp': 81.86,
#   'Humidity': 74,
#   'Cloudiness': 80,
#   'Wind Speed': 21.05,
#   'Country': 'VN',
#   'Current Description': 'broken clouds'},
#  {'City': 'Chacabuco',
#   'Lat': -34.6417,
#   'Lng': -60.4739,
#   'Max Temp': 76.5,
#   'Humidity': 32,
#   'Cloudiness': 0,
#   'Wind Speed': 9.78,
#   'Country': 'AR',
#   'Current Description': 'clear sky'},
#  {'City': 'Aksum',
#   'Lat': 14.1245,
#   'Lng': 38.7244,
#   'Max Temp': 70.83,
#   'Humidity': 30,
#   'Cloudiness': 14,
#   'Wind Speed': 13.85,
#   'Country': 'ET',
#   'Current Description': 'few clouds'},
#  {'City': 'Arzamas',
#   'Lat': 55.3949,
#   'Lng': 43.8399,
#   'Max Temp': 37.98,
#   'Humidity': 91,
#   'Cloudiness': 100,
#   'Wind Speed': 7.11,
#   'Country': 'RU',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Rafiganj',
#   'Lat': 24.8167,
#   'Lng': 84.65,
#   'Max Temp': 87.94,
#   'Humidity': 12,
#   'Cloudiness': 0,
#   'Wind Speed': 6.85,
#   'Country': 'IN',
#   'Current Description': 'clear sky'},
#  {'City': 'Donskoye',
#   'Lat': 45.4552,
#   'Lng': 41.9741,
#   'Max Temp': 65.97,
#   'Humidity': 58,
#   'Cloudiness': 97,
#   'Wind Speed': 11.63,
#   'Country': 'RU',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Kiama',
#   'Lat': -34.6833,
#   'Lng': 150.8667,
#   'Max Temp': 66.58,
#   'Humidity': 86,
#   'Cloudiness': 100,
#   'Wind Speed': 3,
#   'Country': 'AU',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Doka',
#   'Lat': 13.5167,
#   'Lng': 35.7667,
#   'Max Temp': 96.3,
#   'Humidity': 19,
#   'Cloudiness': 93,
#   'Wind Speed': 1.81,
#   'Country': 'SD',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Hamilton',
#   'Lat': 39.1834,
#   'Lng': -84.5333,
#   'Max Temp': 41.09,
#   'Humidity': 87,
#   'Cloudiness': 100,
#   'Wind Speed': 19.57,
#   'Country': 'US',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Oksfjord',
#   'Lat': 70.2396,
#   'Lng': 22.3479,
#   'Max Temp': 42.87,
#   'Humidity': 97,
#   'Cloudiness': 100,
#   'Wind Speed': 8.16,
#   'Country': 'NO',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Yeppoon',
#   'Lat': -23.1333,
#   'Lng': 150.7333,
#   'Max Temp': 67.78,
#   'Humidity': 89,
#   'Cloudiness': 56,
#   'Wind Speed': 7.83,
#   'Country': 'AU',
#   'Current Description': 'broken clouds'},
#  {'City': 'Barrow',
#   'Lat': 71.2906,
#   'Lng': -156.7887,
#   'Max Temp': -5.78,
#   'Humidity': 77,
#   'Cloudiness': 0,
#   'Wind Speed': 5.75,
#   'Country': 'US',
#   'Current Description': 'clear sky'},
#  {'City': 'Talnakh',
#   'Lat': 69.4865,
#   'Lng': 88.3972,
#   'Max Temp': 20.21,
#   'Humidity': 95,
#   'Cloudiness': 100,
#   'Wind Speed': 10.83,
#   'Country': 'RU',
# ...
#   'Max Temp': 81.91,
#   'Humidity': 88,
#   'Cloudiness': 90,
#   'Wind Speed': 2.04,
#   'Country': 'BR',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Salinopolis',
#   'Lat': -0.6136,
#   'Lng': -47.3561,
#   'Max Temp': 82.38,
#   'Humidity': 78,
#   'Cloudiness': 100,
#   'Wind Speed': 8.19,
#   'Country': 'BR',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Warrnambool',
#   'Lat': -38.3833,
#   'Lng': 142.4833,
#   'Max Temp': 56.8,
#   'Humidity': 79,
#   'Cloudiness': 100,
#   'Wind Speed': 9.95,
#   'Country': 'AU',
#   'Current Description': 'moderate rain'},
#  {'City': 'Garden City',
#   'Lat': 42.3256,
#   'Lng': -83.331,
#   'Max Temp': 35.85,
#   'Humidity': 91,
#   'Cloudiness': 100,
#   'Wind Speed': 4.61,
#   'Country': 'US',
#   'Current Description': 'mist'},
#  {'City': 'Sainte-Suzanne',
#   'Lat': -20.9061,
#   'Lng': 55.6089,
#   'Max Temp': 78.98,
#   'Humidity': 88,
#   'Cloudiness': 75,
#   'Wind Speed': 9.22,
#   'Country': 'RE',
#   'Current Description': 'broken clouds'},
#  {'City': 'Ilebo',
#   'Lat': -4.3167,
#   'Lng': 20.5833,
#   'Max Temp': 76.14,
#   'Humidity': 81,
#   'Cloudiness': 91,
#   'Wind Speed': 0.94,
#   'Country': 'CD',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Tyukhtet',
#   'Lat': 56.5389,
#   'Lng': 89.3011,
#   'Max Temp': 29.79,
#   'Humidity': 78,
#   'Cloudiness': 100,
#   'Wind Speed': 6.26,
#   'Country': 'RU',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Adrar',
#   'Lat': 20.5022,
#   'Lng': -10.0711,
#   'Max Temp': 87.55,
#   'Humidity': 11,
#   'Cloudiness': 4,
#   'Wind Speed': 8.68,
#   'Country': 'MR',
#   'Current Description': 'clear sky'},
#  {'City': 'Mayo',
#   'Lat': 38.8876,
#   'Lng': -76.5119,
#   'Max Temp': 50.04,
#   'Humidity': 65,
#   'Cloudiness': 100,
#   'Wind Speed': 16.11,
#   'Country': 'US',
#   'Current Description': 'light rain'},
#  {'City': 'Alyangula',
#   'Lat': -13.8483,
#   'Lng': 136.4192,
#   'Max Temp': 73.27,
#   'Humidity': 100,
#   'Cloudiness': 40,
#   'Wind Speed': 0,
#   'Country': 'AU',
#   'Current Description': 'scattered clouds'},
#  {'City': 'Kloulklubed',
#   'Lat': 7.0419,
#   'Lng': 134.2556,
#   'Max Temp': 77.5,
#   'Humidity': 78,
#   'Cloudiness': 100,
#   'Wind Speed': 7.87,
#   'Country': 'PW',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Coahuayana',
#   'Lat': 18.7333,
#   'Lng': -103.6833,
#   'Max Temp': 89.56,
#   'Humidity': 48,
#   'Cloudiness': 100,
#   'Wind Speed': 8.52,
#   'Country': 'MX',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Lamu',
#   'Lat': -2.2717,
#   'Lng': 40.902,
#   'Max Temp': 82.62,
#   'Humidity': 77,
#   'Cloudiness': 100,
#   'Wind Speed': 11.21,
#   'Country': 'KE',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Russkoye',
#   'Lat': 45.0167,
#   'Lng': 34.8,
#   'Max Temp': 43.97,
#   'Humidity': 93,
#   'Cloudiness': 95,
#   'Wind Speed': 6.29,
#   'Country': 'UA',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Neka',
#   'Lat': 36.6508,
#   'Lng': 53.299,
#   'Max Temp': 54.91,
#   'Humidity': 82,
#   'Cloudiness': 0,
#   'Wind Speed': 2.3,
#   'Country': 'IR',
#   'Current Description': 'clear sky'},
#  {'City': 'Kendari',
#   'Lat': -3.945,
#   'Lng': 122.4989,
#   'Max Temp': 77.79,
#   'Humidity': 90,
#   'Cloudiness': 100,
#   'Wind Speed': 4.32,
#   'Country': 'ID',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Roald',
#   'Lat': 62.5833,
#   'Lng': 6.1333,
#   'Max Temp': 54.52,
#   'Humidity': 71,
#   'Cloudiness': 0,
#   'Wind Speed': 1.14,
#   'Country': 'NO',
#   'Current Description': 'clear sky'},
#  {'City': 'Farah',
#   'Lat': 32.5,
#   'Lng': 62.5,
#   'Max Temp': 58.1,
#   'Humidity': 56,
#   'Cloudiness': 0,
#   'Wind Speed': 9.48,
#   'Country': 'AF',
#   'Current Description': 'light rain'},
#  {'City': 'Inyonga',
#   'Lat': -6.7167,
#   'Lng': 32.0667,
#   'Max Temp': 66.76,
#   'Humidity': 85,
#   'Cloudiness': 35,
#   'Wind Speed': 5.41,
#   'Country': 'TZ',
#   'Current Description': 'scattered clouds'},
#  {'City': 'San Juan De Los Morros',
#   'Lat': 9.9115,
#   'Lng': -67.3538,
#   'Max Temp': 86.16,
#   'Humidity': 45,
#   'Cloudiness': 95,
#   'Wind Speed': 4.7,
#   'Country': 'VE',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Nioro',
#   'Lat': 13.35,
#   'Lng': -15.75,
#   'Max Temp': 89.2,
#   'Humidity': 29,
#   'Cloudiness': 9,
#   'Wind Speed': 13.15,
#   'Country': 'GM',
#   'Current Description': 'clear sky'},
#  {'City': 'Rincon',
#   'Lat': 32.296,
#   'Lng': -81.2354,
#   'Max Temp': 78.94,
#   'Humidity': 67,
#   'Cloudiness': 75,
#   'Wind Speed': 16.11,
#   'Country': 'US',
#   'Current Description': 'broken clouds'},
#  {'City': 'Maneadero',
#   'Lat': 31.7167,
#   'Lng': -116.5667,
#   'Max Temp': 66.09,
#   'Humidity': 78,
#   'Cloudiness': 10,
#   'Wind Speed': 3,
#   'Country': 'MX',
#   'Current Description': 'clear sky'},
#  {'City': 'Cabedelo',
#   'Lat': -6.9811,
#   'Lng': -34.8339,
#   'Max Temp': 88.47,
#   'Humidity': 70,
#   'Cloudiness': 97,
#   'Wind Speed': 9.62,
#   'Country': 'BR',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Zhangjiakou',
#   'Lat': 40.81,
#   'Lng': 114.8794,
#   'Max Temp': 50.86,
#   'Humidity': 27,
#   'Cloudiness': 0,
#   'Wind Speed': 3.94,
#   'Country': 'CN',
#   'Current Description': 'clear sky'},
#  {'City': 'Vuktyl',
#   'Lat': 63.8567,
#   'Lng': 57.3094,
#   'Max Temp': 30.92,
#   'Humidity': 95,
#   'Cloudiness': 100,
#   'Wind Speed': 4.7,
#   'Country': 'RU',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Thinadhoo',
#   'Lat': 0.5333,
#   'Lng': 72.9333,
#   'Max Temp': 83.53,
#   'Humidity': 70,
#   'Cloudiness': 100,
#   'Wind Speed': 3.87,
#   'Country': 'MV',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Mazamari',
#   'Lat': -11.3258,
#   'Lng': -74.5308,
#   'Max Temp': 84.69,
#   'Humidity': 56,
#   'Cloudiness': 84,
#   'Wind Speed': 2.44,
#   'Country': 'PE',
#   'Current Description': 'broken clouds'},
#  {'City': 'Kentau',
#   'Lat': 43.5206,
#   'Lng': 68.5094,
#   'Max Temp': 70,
#   'Humidity': 38,
#   'Cloudiness': 100,
#   'Wind Speed': 10.4,
#   'Country': 'KZ',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Urumqi',
#   'Lat': 43.801,
#   'Lng': 87.6005,
#   'Max Temp': 68.95,
#   'Humidity': 8,
#   'Cloudiness': 0,
#   'Wind Speed': 20.13,
#   'Country': 'CN',
#   'Current Description': 'clear sky'},
#  {'City': 'Sisimiut',
#   'Lat': 66.9395,
#   'Lng': -53.6735,
#   'Max Temp': 14.27,
#   'Humidity': 76,
#   'Cloudiness': 100,
#   'Wind Speed': 11.07,
#   'Country': 'GL',
#   'Current Description': 'light snow'},
#  {'City': 'Ocampo',
#   'Lat': 21.65,
#   'Lng': -101.5,
#   'Max Temp': 81.14,
#   'Humidity': 24,
#   'Cloudiness': 0,
#   'Wind Speed': 12.82,
#   'Country': 'MX',
#   'Current Description': 'clear sky'},
#  {'City': 'Shenjiamen',
#   'Lat': 29.9576,
#   'Lng': 122.298,
#   'Max Temp': 55.49,
#   'Humidity': 73,
#   'Cloudiness': 100,
#   'Wind Speed': 4.72,
#   'Country': 'CN',
#   'Current Description': 'overcast clouds'},
#  {'City': 'San Andres',
#   'Lat': 12.5847,
#   'Lng': -81.7006,
#   'Max Temp': 86.02,
#   'Humidity': 70,
#   'Cloudiness': 20,
#   'Wind Speed': 8.05,
#   'Country': 'CO',
#   'Current Description': 'few clouds'},
#  {'City': 'Benito Juarez',
#   'Lat': 19.385,
#   'Lng': -99.165,
#   'Max Temp': 81,
#   'Humidity': 18,
#   'Cloudiness': 81,
#   'Wind Speed': 3,
#   'Country': 'MX',
#   'Current Description': 'broken clouds'},
#  {'City': 'Mazatlan',
#   'Lat': 23.2167,
#   'Lng': -106.4167,
#   'Max Temp': 78.91,
#   'Humidity': 75,
#   'Cloudiness': 67,
#   'Wind Speed': 4,
#   'Country': 'MX',
#   'Current Description': 'broken clouds'},
#  {'City': 'Kismayo',
#   'Lat': -0.3582,
#   'Lng': 42.5454,
#   'Max Temp': 82.53,
#   'Humidity': 77,
#   'Cloudiness': 100,
#   'Wind Speed': 8.7,
#   'Country': 'SO',
#   'Current Description': 'light rain'},
#  {'City': 'Aasiaat',
#   'Lat': 68.7098,
#   'Lng': -52.8699,
#   'Max Temp': 11.55,
#   'Humidity': 80,
#   'Cloudiness': 100,
#   'Wind Speed': 12.17,
#   'Country': 'GL',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Balikpapan',
#   'Lat': -1.2675,
#   'Lng': 116.8289,
#   'Max Temp': 77.99,
#   'Humidity': 100,
#   'Cloudiness': 40,
#   'Wind Speed': 3.44,
#   'Country': 'ID',
#   'Current Description': 'scattered clouds'},
#  {'City': 'Buenos Aires',
#   'Lat': -34.6132,
#   'Lng': -58.3772,
#   'Max Temp': 73.98,
#   'Humidity': 64,
#   'Cloudiness': 20,
#   'Wind Speed': 5.75,
#   'Country': 'AR',
#   'Current Description': 'few clouds'},
#  {'City': 'Balkhash',
#   'Lat': 46.844,
#   'Lng': 74.9804,
#   'Max Temp': 58.17,
#   'Humidity': 32,
#   'Cloudiness': 86,
#   'Wind Speed': 5.1,
#   'Country': 'KZ',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Darnah',
#   'Lat': 32.767,
#   'Lng': 22.6367,
#   'Max Temp': 60.57,
#   'Humidity': 65,
#   'Cloudiness': 6,
#   'Wind Speed': 18.54,
#   'Country': 'LY',
#   'Current Description': 'clear sky'},
#  {'City': 'Hovd',
#   'Lat': 48.0056,
#   'Lng': 91.6419,
#   'Max Temp': 48,
#   'Humidity': 22,
#   'Cloudiness': 100,
#   'Wind Speed': 9.19,
#   'Country': 'MN',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Kalabo',
#   'Lat': -14.97,
#   'Lng': 22.6814,
#   'Max Temp': 69.78,
#   'Humidity': 76,
#   'Cloudiness': 100,
#   'Wind Speed': 4.97,
#   'Country': 'ZM',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Jiexiu',
#   'Lat': 37.0244,
#   'Lng': 111.9125,
#   'Max Temp': 51.08,
#   'Humidity': 43,
#   'Cloudiness': 0,
#   'Wind Speed': 3.76,
#   'Country': 'CN',
#   'Current Description': 'clear sky'},
#  {'City': 'Khasan',
#   'Lat': 42.4308,
#   'Lng': 130.6434,
#   'Max Temp': 41.04,
#   'Humidity': 64,
#   'Cloudiness': 0,
#   'Wind Speed': 1.05,
#   'Country': 'RU',
#   'Current Description': 'clear sky'},
#  {'City': 'Bandarbeyla',
#   'Lat': 9.4942,
#   'Lng': 50.8122,
#   'Max Temp': 81.82,
#   'Humidity': 79,
#   'Cloudiness': 1,
#   'Wind Speed': 9.55,
#   'Country': 'SO',
#   'Current Description': 'clear sky'},
#  {'City': 'Lombardia',
#   'Lat': 19.15,
#   'Lng': -102.0333,
#   'Max Temp': 97.45,
#   'Humidity': 10,
#   'Cloudiness': 44,
#   'Wind Speed': 6.49,
#   'Country': 'MX',
#   'Current Description': 'scattered clouds'},
#  {'City': 'Asfi',
#   'Lat': 32.2994,
#   'Lng': -9.2372,
#   'Max Temp': 63.57,
#   'Humidity': 83,
#   'Cloudiness': 53,
#   'Wind Speed': 16.67,
#   'Country': 'MA',
#   'Current Description': 'broken clouds'},
#  {'City': 'Carhuamayo',
#   'Lat': -10.9167,
#   'Lng': -76.0333,
#   'Max Temp': 53.74,
#   'Humidity': 36,
#   'Cloudiness': 100,
#   'Wind Speed': 10.29,
#   'Country': 'PE',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Champerico',
#   'Lat': 14.3,
#   'Lng': -91.9167,
#   'Max Temp': 95.54,
#   'Humidity': 63,
#   'Cloudiness': 11,
#   'Wind Speed': 12.75,
#   'Country': 'GT',
#   'Current Description': 'few clouds'},
#  {'City': 'Castro Verde',
#   'Lat': 37.6983,
#   'Lng': -8.0858,
#   'Max Temp': 65.62,
#   'Humidity': 62,
#   'Cloudiness': 0,
#   'Wind Speed': 19.22,
#   'Country': 'PT',
#   'Current Description': 'clear sky'},
#  {'City': 'Castlemaine',
#   'Lat': -37.0667,
#   'Lng': 144.2167,
#   'Max Temp': 56.28,
#   'Humidity': 96,
#   'Cloudiness': 100,
#   'Wind Speed': 1.81,
#   'Country': 'AU',
#   'Current Description': 'light rain'},
#  {'City': 'Wuwei',
#   'Lat': 37.9281,
#   'Lng': 102.6414,
#   'Max Temp': 46.63,
#   'Humidity': 50,
#   'Cloudiness': 100,
#   'Wind Speed': 12.37,
#   'Country': 'CN',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Fortuna Foothills',
#   'Lat': 32.6578,
#   'Lng': -114.4119,
#   'Max Temp': 92.21,
#   'Humidity': 10,
#   'Cloudiness': 0,
#   'Wind Speed': 10.36,
#   'Country': 'US',
#   'Current Description': 'clear sky'},
#  {'City': 'Saint Simons',
#   'Lat': 31.1352,
#   'Lng': -81.3901,
#   'Max Temp': 78.85,
#   'Humidity': 57,
#   'Cloudiness': 40,
#   'Wind Speed': 12.66,
#   'Country': 'US',
#   'Current Description': 'scattered clouds'},
#  {'City': 'Marsh Harbour',
#   'Lat': 26.5412,
#   'Lng': -77.0636,
#   'Max Temp': 77.36,
#   'Humidity': 75,
#   'Cloudiness': 80,
#   'Wind Speed': 7.76,
#   'Country': 'BS',
#   'Current Description': 'broken clouds'},
#  {'City': 'Maloy',
#   'Lat': 61.9353,
#   'Lng': 5.1136,
#   'Max Temp': 51.53,
#   'Humidity': 65,
#   'Cloudiness': 0,
#   'Wind Speed': 7.58,
#   'Country': 'NO',
#   'Current Description': 'clear sky'},
#  {'City': 'Santa Maria',
#   'Lat': -29.6842,
#   'Lng': -53.8069,
#   'Max Temp': 76.3,
#   'Humidity': 53,
#   'Cloudiness': 40,
#   'Wind Speed': 6.91,
#   'Country': 'BR',
#   'Current Description': 'scattered clouds'},
#  {'City': 'Antalaha',
#   'Lat': -14.9003,
#   'Lng': 50.2788,
#   'Max Temp': 74.75,
#   'Humidity': 88,
#   'Cloudiness': 96,
#   'Wind Speed': 7.7,
#   'Country': 'MG',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Hanko',
#   'Lat': 59.8333,
#   'Lng': 22.95,
#   'Max Temp': 40.14,
#   'Humidity': 81,
#   'Cloudiness': 34,
#   'Wind Speed': 1.92,
#   'Country': 'FI',
#   'Current Description': 'scattered clouds'},
#  {'City': 'Vikhorevka',
#   'Lat': 56.1201,
#   'Lng': 101.1636,
#   'Max Temp': 35.19,
#   'Humidity': 81,
#   'Cloudiness': 100,
#   'Wind Speed': 9.71,
#   'Country': 'RU',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Caluquembe',
#   'Lat': -13.7833,
#   'Lng': 14.6833,
#   'Max Temp': 61.43,
#   'Humidity': 93,
#   'Cloudiness': 100,
#   'Wind Speed': 3.76,
#   'Country': 'AO',
#   'Current Description': 'light rain'},
#  {'City': 'Torbat-E Jam',
#   'Lat': 35.244,
#   'Lng': 60.6225,
#   'Max Temp': 50.4,
#   'Humidity': 71,
#   'Cloudiness': 100,
#   'Wind Speed': 15.32,
#   'Country': 'IR',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Skjervoy',
#   'Lat': 70.0311,
#   'Lng': 20.9714,
#   'Max Temp': 48.2,
#   'Humidity': 91,
#   'Cloudiness': 100,
#   'Wind Speed': 7.94,
#   'Country': 'NO',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Can',
#   'Lat': 40.0333,
#   'Lng': 27.0524,
#   'Max Temp': 42.55,
#   'Humidity': 98,
#   'Cloudiness': 100,
#   'Wind Speed': 7.38,
#   'Country': 'TR',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Sampit',
#   'Lat': -2.5333,
#   'Lng': 112.95,
#   'Max Temp': 76.39,
#   'Humidity': 91,
#   'Cloudiness': 99,
#   'Wind Speed': 2.17,
#   'Country': 'ID',
#   'Current Description': 'moderate rain'},
#  {'City': 'Qingdao',
#   'Lat': 36.0986,
#   'Lng': 120.3719,
#   'Max Temp': 49.6,
#   'Humidity': 71,
#   'Cloudiness': 1,
#   'Wind Speed': 2.24,
#   'Country': 'CN',
#   'Current Description': 'haze'},
#  {'City': 'Malkangiri',
#   'Lat': 18.35,
#   'Lng': 81.9,
#   'Max Temp': 84.92,
#   'Humidity': 44,
#   'Cloudiness': 4,
#   'Wind Speed': 2.53,
#   'Country': 'IN',
#   'Current Description': 'clear sky'},
#  {'City': 'Wladyslawowo',
#   'Lat': 54.7909,
#   'Lng': 18.4009,
#   'Max Temp': 45.93,
#   'Humidity': 68,
#   'Cloudiness': 100,
#   'Wind Speed': 10,
#   'Country': 'PL',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Malayal',
#   'Lat': 7.208,
#   'Lng': 121.942,
#   'Max Temp': 76.8,
#   'Humidity': 82,
#   'Cloudiness': 78,
#   'Wind Speed': 2.71,
#   'Country': 'PH',
#   'Current Description': 'broken clouds'},
#  {'City': 'Yazd',
#   'Lat': 31.8972,
#   'Lng': 54.3675,
#   'Max Temp': 62.71,
#   'Humidity': 19,
#   'Cloudiness': 0,
#   'Wind Speed': 6.91,
#   'Country': 'IR',
#   'Current Description': 'clear sky'},
#  {'City': 'Bagar',
#   'Lat': 28.1874,
#   'Lng': 75.5005,
#   'Max Temp': 85.55,
#   'Humidity': 17,
#   'Cloudiness': 1,
#   'Wind Speed': 8.59,
#   'Country': 'IN',
#   'Current Description': 'clear sky'},
#  {'City': 'Sweetwater',
#   'Lat': 25.7634,
#   'Lng': -80.3731,
#   'Max Temp': 90,
#   'Humidity': 62,
#   'Cloudiness': 75,
#   'Wind Speed': 8.05,
#   'Country': 'US',
#   'Current Description': 'broken clouds'},
#  {'City': 'Asau',
#   'Lat': 46.4333,
#   'Lng': 26.4,
#   'Max Temp': 37.96,
#   'Humidity': 64,
#   'Cloudiness': 92,
#   'Wind Speed': 3.56,
#   'Country': 'RO',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Basco',
#   'Lat': 20.4487,
#   'Lng': 121.9702,
#   'Max Temp': 77.09,
#   'Humidity': 82,
#   'Cloudiness': 51,
#   'Wind Speed': 16.69,
#   'Country': 'PH',
#   'Current Description': 'broken clouds'},
#  {'City': 'Barra Do Garcas',
#   'Lat': -15.89,
#   'Lng': -52.2567,
#   'Max Temp': 93.78,
#   'Humidity': 38,
#   'Cloudiness': 40,
#   'Wind Speed': 3.44,
#   'Country': 'BR',
#   'Current Description': 'scattered clouds'},
#  {'City': 'Vlagtwedde',
#   'Lat': 53.0275,
#   'Lng': 7.1083,
#   'Max Temp': 59.25,
#   'Humidity': 64,
#   'Cloudiness': 0,
#   'Wind Speed': 7.83,
#   'Country': 'NL',
#   'Current Description': 'clear sky'},
#  {'City': 'Konya',
#   'Lat': 38.1667,
#   'Lng': 32.5,
#   'Max Temp': 53.65,
#   'Humidity': 40,
#   'Cloudiness': 0,
#   'Wind Speed': 1.95,
#   'Country': 'TR',
#   'Current Description': 'clear sky'},
#  {'City': 'Puerto Colombia',
#   'Lat': 10.9878,
#   'Lng': -74.9547,
#   'Max Temp': 78.89,
#   'Humidity': 76,
#   'Cloudiness': 27,
#   'Wind Speed': 12.26,
#   'Country': 'CO',
#   'Current Description': 'scattered clouds'}]
